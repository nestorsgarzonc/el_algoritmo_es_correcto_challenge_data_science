# %%
import pandas as pd
import numpy as np

# %%
from google.colab import drive
drive.mount('/gdrive')
PATH='/gdrive/My Drive/ALGORITMOCORRECTO/'
# Out:
# Mounted at /gdrive

# %%
df=pd.read_csv(f'{PATH}/frankenstainV2.csv')
# Out:
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:2718: DtypeWarning: Columns (42) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
df.head()
# Out:
#    Unnamed: 0  field_1       id  ...  RESPONSABL  SHAPE_Leng    SHAPE_Area
# 0           0        3  1125506  ...         560  455.443840  11733.285572
# 1           1        4  1204569  ...         560  526.725354  13106.715958
# 2           2        8   958538  ...         560  907.395275  43417.200831
# 3           3       12  1084087  ...         560  117.397560    832.537824
# 4           4       13  1204653  ...         560  227.998274   2922.622559
#
# [5 rows x 52 columns]

# %%
pd.options.display.float_format = '{:,.5f}'.format

# %%
df
# Out:
#         Unnamed: 0  field_1       id  ...  RESPONSABL  SHAPE_Leng   SHAPE_Area
# 0                0        3  1125506  ...         560   455.44384 11,733.28557
# 1                1        4  1204569  ...         560   526.72535 13,106.71596
# 2                2        8   958538  ...         560   907.39527 43,417.20083
# 3                3       12  1084087  ...         560   117.39756    832.53782
# 4                4       13  1204653  ...         560   227.99827  2,922.62256
# ...            ...      ...      ...  ...         ...         ...          ...
# 136235      136235   244425  1403961  ...         560   510.65670 14,347.74848
# 136236      136236   244430  1393020  ...         560   240.00359  2,699.82037
# 136237      136237   244431   490880  ...         560   538.26785 16,035.20752
# 136238      136238   244432  1383758  ...         560   755.33828 28,571.90781
# 136239      136239   244433  1381410  ...         560   941.93076 22,603.30703
#
# [136240 rows x 52 columns]

# %% [markdown]
# ## Delete dummy variables

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'field_1', 'id', 'area', 'ascensor', 'balcon', 'banos',
#        'banoservicio', 'conjuntocerrado', 'cuartoservicio', 'deposito',
#        'estrato', 'estudio', 'garajes', 'gimnasio', 'habitaciones',
#        'halldealcobas', 'parqueaderovisitantes', 'piscina', 'piso', 'porteria',
#        'remodelado', 'saloncomunal', 'terraza', 'tiempodeconstruido',
#        'vigilancia', 'vista', 'zonalavanderia', 'valoradministracion',
#        'valorventa', 'tipoinmueble', 'tiponegocio', 'latitud', 'longitud',
#        'val_mcuadrado', '0-1 anos', '1-10 anos', '10-30 anos', '30 anos',
#        'CODIGO_MAN', 'ESTRATO_2', 'CODIGO_ZON', 'CODIGO_CRI', 'NORMATIVA',
#        'ACTO_ADMIN', 'NUMERO_ACT', 'FECHA_ACTO', 'ESCALA_CAP', 'FECHA_CAPT',
#        'RESPONSABL', 'SHAPE_Leng', 'SHAPE_Area'],
#       dtype='object')

# %%
columns_to_delete=[
                   'conjuntocerrado',
                   'Unnamed: 0',
                   'field_1',
                    'id',
                    'ascensor',
                    'balcon',
                    'cuartoservicio',
                    'deposito',
                    'estudio',
                    'gimnasio',
                    'halldealcobas',
                    'parqueaderovisitantes',
                    'piscina',
                    'porteria' ,
                    'remodelado',
                    'saloncomunal',
                    'terraza',
                    'vigilancia',
                    'vista',
                    'zonalavanderia',
                    'CODIGO_MAN',
                    'ESTRATO_2',
                    'CODIGO_ZON',
                    'CODIGO_CRI',
                    'NORMATIVA',
                    'ACTO_ADMIN',
                    'NUMERO_ACT',
                    'FECHA_ACTO',
                    'ESCALA_CAP',
                    'FECHA_CAPT',
                    'RESPONSABL',
                    'SHAPE_Leng',
                    'SHAPE_Area',
                   'tiempodeconstruido',
                   'banoservicio',
                   ]

# %%
# %%time
# df['piso'] = df['piso'].replace(np.nan, 1)

# %%
# %%time
df['piso'] = df['piso'].fillna(1)

# %%
df['garajes'] = df['garajes'].fillna(method='ffill')

# %%
df.describe()
# Out:
#          Unnamed: 0       field_1  ...    SHAPE_Leng      SHAPE_Area
# count 136,240.00000 136,240.00000  ... 136,240.00000   136,240.00000
# mean   68,119.50000 125,152.08219  ...     765.96687    48,963.53198
# std    39,329.24467  70,534.46113  ...     848.39833   176,017.90625
# min         0.00000       3.00000  ...      50.38536       120.78306
# 25%    34,059.75000  63,352.50000  ...     367.29184     6,885.42907
# 50%    68,119.50000 128,341.50000  ...     529.42877    12,906.35311
# 75%   102,179.25000 185,680.50000  ...     833.61709    30,788.83975
# max   136,239.00000 244,433.00000  ...  15,822.56292 6,786,206.48621
#
# [8 rows x 42 columns]

# %%
import seaborn as sb

# %%
df=df[(df.banos>0) & (df.banos<20)]

# %%
def delete_garbage_columns(df):
  for i in columns_to_delete:
    try:
      df.pop(i)
    except Exception as e:
      print(e)
  return df

# %%
df = delete_garbage_columns(df)

# %%
df.head()
# Out:
#          area   banos  estrato  ...  1-10 anos  10-30 anos  30 anos
# 982  51.00000 2.00000        2  ...          0           0        0
# 983 172.00000 2.00000        3  ...          0           0        0
# 984 144.00000 2.00000        2  ...          0           0        0
# 985 132.25000 2.00000        2  ...          0           0        0
# 986 134.00000 2.00000        1  ...          0           0        0
#
# [5 rows x 17 columns]

# %% [markdown]
# ## Add onehot encoding to category variables

# %%
def AddOnehotEncoding(df):
  
  try:
    one_hot_magic={
      '0-1 anos': ['Menos de 1 año'],
      '1-10 anos': ['ntre 0 y 5 años', 'Entre 0 y 5 años', '1 a 8 años', 'Entre 5 y 10 años'],
      '10-30 anos': ['9 a 15 años', 'Entre 10 y 20 años', '16 a 30 años', 'Más de 20 años'],
      '30 anos': ['Más de 30 años'],
    }
    d = []
    for k, v in one_hot_magic.items():
      a = pd.Series([])
      for y in v:
        if len(df.value_counts()) <= 0:
          a=df.tiempodeconstruido == y
        else:
          a= a | df.tiempodeconstruido == y
      df[k] = a
      df[k]=df[k].replace(True, 1).replace(False, 0).astype(int)
  except Exception as e:
    print(e) 
  tiponegocio = pd.get_dummies(df.tiponegocio, prefix='tiponegocio')
  columns = tiponegocio.columns

  df['tiponegocio_Arriendo'] = tiponegocio['tiponegocio_Arriendo'] if 'tiponegocio_Arriendo' in columns else 0
  df['tiponegocio_Venta'] = tiponegocio['tiponegocio_Venta'] if 'tiponegocio_Venta' in columns else 0
  df['tiponegocio_Venta Y Arriendo'] = tiponegocio['tiponegocio_Venta Y Arriendo']+tiponegocio['tiponegocio_Venta y arriendo']	if 'tiponegocio_Venta Y Arriendo' in columns and 'tiponegocio_Venta y arriendo' in columns else 0
  df.pop('tiponegocio')

  tipoinmueble  = pd.get_dummies(df.tipoinmueble , prefix='tipoinmueble')

  df.pop('tipoinmueble')
  columns = tipoinmueble.columns
  df['tipoinmueble_Casa'] = tipoinmueble['tipoinmueble_Casa'] if 'tipoinmueble_Casa' in columns else 0
  df['tipoinmueble_Apartamento'] = tipoinmueble['tipoinmueble_Apartamento'] if 'tipoinmueble_Apartamento' in columns else 0   
  return df

# %%
df = AddOnehotEncoding(df)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:12: DeprecationWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   if sys.path[0] == '':
# 'DataFrame' object has no attribute 'tiempodeconstruido'
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:34: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:35: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %% [markdown]
# #Eliminar las variables a buscar

# %%
val_m=df.pop('val_mcuadrado')
df.pop('valorventa')
# Out:
# 982       130070000
# 983       470000000
# 984       108000000
# 985       149900000
# 986       140000000
#             ...
# 136224    120000000
# 136225    135000000
# 136226    167000000
# 136227    158000000
# 136228    138000000
# Name: valorventa, Length: 134910, dtype: int64

# %%
val_m.head()
# Out:
# 982   2,550,392.15686
# 983   2,732,558.13953
# 984     750,000.00000
# 985   1,133,459.35728
# 986   1,044,776.11940
# Name: val_mcuadrado, dtype: float64

# %%
import datetime
import pytz
colombia_time = pytz.timezone('America/Bogota')
def get_date():
  date = datetime.datetime.now(colombia_time)
  return date.strftime('%Y-%B-%d-%H:%M:%S')

# %%
df.to_csv(f'{PATH}/desconfianza_{get_date()}.csv')

# %%
df.head()
# Out:
#          area   banos  ...  tipoinmueble_Casa  tipoinmueble_Apartamento
# 982  51.00000 2.00000  ...                  0                         1
# 983 172.00000 2.00000  ...                  1                         0
# 984 144.00000 2.00000  ...                  1                         0
# 985 132.25000 2.00000  ...                  1                         0
# 986 134.00000 2.00000  ...                  1                         0
#
# [5 rows x 18 columns]

# %% [markdown]
# ## Load validation data

# %%
test_data=pd.read_csv(f'{PATH}/test_data.csv')

# %%
test_data = AddOnehotEncoding(test_data)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:12: DeprecationWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   if sys.path[0] == '':

# %%
test_data = delete_garbage_columns(test_data)
# Out:
# 'Unnamed: 0'
# 'field_1'
# 'CODIGO_MAN'
# 'ESTRATO_2'
# 'CODIGO_ZON'
# 'CODIGO_CRI'
# 'NORMATIVA'
# 'ACTO_ADMIN'
# 'NUMERO_ACT'
# 'FECHA_ACTO'
# 'ESCALA_CAP'
# 'FECHA_CAPT'
# 'RESPONSABL'
# 'SHAPE_Leng'
# 'SHAPE_Area'

# %%
val_m_test = test_data.valorventa/test_data.area
test_data.pop('valorventa')
# Out:
# 0    185,000,000.00000
# 1    498,000,000.00000
# 2    498,000,000.00000
# 3    519,000,000.00000
# 4    517,000,000.00000
# 5    514,990,000.00000
# 6    510,000,000.00000
# 7    520,000,000.00000
# 8    215,000,000.00000
# 9    519,000,000.00000
# 10   517,000,000.00000
# 11   519,000,000.00000
# 12   513,990,000.00000
# 13   514,660,000.00000
# 14   513,330,000.00000
# 15   514,330,000.00000
# 16   570,000,000.00000
# 17   310,000,000.00000
# 18   330,000,000.00000
# 19   330,000,000.00000
# 20   350,000,000.00000
# 21   320,000,000.00000
# 22   350,000,000.00000
# 23   330,000,000.00000
# 24   350,000,000.00000
# 25   315,000,000.00000
# 26   330,000,000.00000
# 27   330,000,000.00000
# 28   310,000,000.00000
# 29   350,000,000.00000
# 30   300,000,000.00000
# 31   330,000,000.00000
# 32   290,000,000.00000
# 33   290,000,000.00000
# 34   300,000,000.00000
# 35   310,000,000.00000
# 36   370,000,000.00000
# 37   390,000,000.00000
# 38   390,000,000.00000
# 39   370,000,000.00000
# 40   370,000,000.00000
# 41   360,000,000.00000
# 42   370,000,000.00000
# 43   370,000,000.00000
# 44   370,000,000.00000
# 45   370,000,000.00000
# 46   370,000,000.00000
# 47   799,000,000.00000
# 48   799,000,000.00000
# 49   749,000,000.00000
# 50   749,000,000.00000
# 51   699,000,000.00000
# 52   930,000,000.00000
# Name: valorventa, dtype: float64

# %%
val_m_test.head()
# Out:
# 0   1,778,846.15385
# 1   3,458,333.33333
# 2   3,458,333.33333
# 3   3,579,310.34483
# 4   3,565,517.24138
# dtype: float64

# %%
test_data.head()
# Out:
#        area   banos  ...  tipoinmueble_Casa  tipoinmueble_Apartamento
# 0 104.00000 2.00000  ...                  1                         0
# 1 144.00000 2.00000  ...                  1                         0
# 2 144.00000 2.00000  ...                  1                         0
# 3 145.00000 2.00000  ...                  1                         0
# 4 145.00000 2.00000  ...                  1                         0
#
# [5 rows x 18 columns]

# %%
len(test_data.columns)
# Out:
# 18

# %%
import tensorflow as tf
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import Conv1D
from tensorflow.keras.layers import Dropout
from tensorflow.keras.layers import Input
from tensorflow.keras.layers import MaxPooling1D
from tensorflow.keras.layers import Flatten

# %%
import os
import datetime

# %%
#Tensorboard config
# %load_ext tensorboard
logdir = os.path.join("logs", datetime.datetime.now().strftime("%Y%m%d-%H%M%S"))
tensorboard_callback = tf.keras.callbacks.TensorBoard(logdir)

# %%
model=tf.keras.models.Sequential(
    [
     Input(shape=(18,)),
    #  Conv1D(9, 3),
    #  Conv1D(64, 3),
    #  Conv1D(128, 3),
    #  Flatten(),
     Dense(25, activation='relu'),
     Dense(10, activation='relu'),
     Dense(1)
    ]
)

# %%
model.compile(loss=tf.keras.losses.MeanAbsolutePercentageError(), optimizer='adam', metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential_15"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_45 (Dense)             (None, 25)                475
# _________________________________________________________________
# dense_46 (Dense)             (None, 10)                260
# _________________________________________________________________
# dense_47 (Dense)             (None, 1)                 11
# =================================================================
# Total params: 746
# Trainable params: 746
# Non-trainable params: 0
# _________________________________________________________________

# %%
from tensorflow.keras.callbacks import ModelCheckpoint

# %%
model.fit(
    x=df, 
    y=val_m,
    validation_data=(test_data, val_m_test),
    batch_size=32, 
    epochs=2000,
    callbacks=[tensorboard_callback, ModelCheckpoint(PATH+'/weights_l/weights.{epoch:02d}-{val_loss:.2f}.h5', verbose=1)]
    )
# Out:
# Se truncaron las últimas líneas 5000 del resultado de transmisión.
# Epoch 751/2000
# 4216/4216 [==============================] - 11s 3ms/step - loss: 17.5878 - accuracy: 0.0000e+00 - val_loss: 64.2331 - val_accuracy: 0.0000e+00
#
# Epoch 00751: saving model to /gdrive/My Drive/ALGORITMOCORRECTO//weights_l/weights.751-64.23.h5
# Epoch 752/2000
# 4216/4216 [==============================] - 11s 3ms/step - loss: 17.5722 - accuracy: 0.0000e+00 - val_loss: 67.1120 - val_accuracy: 0.0000e+00
#
# Epoch 00752: saving model to /gdrive/My Drive/ALGORITMOCORRECTO//weights_l/weights.752-67.11.h5
# Epoch 753/2000
# 4216/4216 [==============================] - 11s 3ms/step - loss: 17.5690 - accuracy: 0.0000e+00 - val_loss: 64.5318 - val_accuracy: 0.0000e+00
#
# Epoch 00753: saving model to /gdrive/My Drive/ALGORITMOCORRECTO//weights_l/weights.753-64.53.h5
# Epoch 754/2000
# 4216/4216 [==============================] - 11s 3ms/step - loss: 17.5494 - accuracy: 0.0000e+00 - val_loss: 63.8088 - val_accuracy: 0.0000e+00
#
# Epoch 00754: saving model to /gdrive/My Drive/ALGORITMOCORRECTO//weights_l/weights.754-63.81.h5
# Epoch 755/2000
# 4216/4216 [==============================] - 11s 3ms/step - loss: 17.5881 - accuracy: 0.0000e+00 - val_loss: 65.1247 - val_accuracy: 0.0000e+00
#
# Epoch 00755: saving model to /gdrive/My Drive/ALGORITMOCORRECTO//weights_l/weights.755-65.12.h5
# Epoch 756/2000
# 4216/4216 [==============================] - 11s 3ms/step - loss: 17.5884 - accuracy: 0.0000e+00 - val_loss: 65.2093 - val_accuracy: 0.0000e+00
#
# Epoch 00756: saving model to /gdrive/My Drive/ALGORITMOCORRECTO//weights_l/weights.756-65.21.h5
# Epoch 757/2000
# 4216/4216 [==============================] - 11s 3ms/step - loss: 17.5705 - accuracy: 0.0000e+00 - val_loss: 63.9616 - val_accuracy: 0.0000e+00
#
# Epoch 00757: saving model to /gdrive/My Drive/ALGORITMOCORRECTO//weights_l/weights.757-63.96.h5
# Epoch 758/2000
# 4216/4216 [==============================] - 11s 3ms/step - loss: 17.6005 - accuracy: 0.0000e+00 - val_loss: 64.4749 - val_accuracy: 0.0000e+00
#
# Epoch 00758: saving model to /gdrive/My Drive/ALGORITMOCORRECTO//weights_l/weights.758-64.47.h5
# Epoch 759/2000
# 4216/4216 [==============================] - 11s 3ms/step - loss: 17.5997 - accuracy: 0.0000e+00 - val_loss: 63.3344 - val_accuracy: 0.0000e+00
#
# Epoch 00759: saving model to /gdrive/My Drive/ALGORITMOCORRECTO//weights_l/weights.759-63.33.h5
# Epoch 760/2000
# 4216/4216 [==============================] - 11s 3ms/step - loss: 17.5997 - accuracy: 0.0000e+00 - val_loss: 64.6805 - val_accuracy: 0.0000e+00
#
# Epoch 00760: saving model to /gdrive/My Drive/ALGORITMOCORRECTO//weights_l/weights.760-64.68.h5
# Epoch 761/2000
# 4216/4216 [==============================] - 11s 3ms/step - loss: 17.5615 - accuracy: 0.0000e+00 - val_loss: 64.6817 - val_accuracy: 0.0000e+00
#
# Epoch 00761: saving model to /gdrive/My Drive/ALGORITMOCORRECTO//weights_l/weights.761-64.68.h5
# Epoch 762/2000
# 4216/4216 [==============================] - 12s 3ms/step - loss: 17.5900 - accuracy: 0.0000e+00 - val_loss: 64.1319 - val_accuracy: 0.0000e+00
#
# Epoch 00762: saving model to /gdrive/My Drive/ALGORITMOCORRECTO//weights_l/weights.762-64.13.h5
# Epoch 763/2000
# 4216/4216 [==============================] - 11s 3ms/step - loss: 17.5333 - accuracy: 0.0000e+00 - val_loss: 64.4586 - val_accuracy: 0.0000e+00
#
# Epoch 00763: saving model to /gdrive/My Drive/ALGORITMOCORRECTO//weights_l/weights.763-64.46.h5
# Epoch 764/2000
# 4216/4216 [==============================] - 11s 3ms/step - loss: 17.5375 - accuracy: 0.0000e+00 - val_loss: 65.2557 - val_accuracy: 0.0000e+00
#
# Epoch 00764: saving model to /gdrive/My Drive/ALGORITMOCORRECTO//weights_l/weights.764-65.26.h5
# Epoch 765/2000
# 4216/4216 [==============================] - 11s 3ms/step - loss: 17.5526 - accuracy: 0.0000e+00 - val_loss: 65.2169 - val_accuracy: 0.0000e+00
#
# Epoch 00765: saving model to /gdrive/My Drive/ALGORITMOCORRECTO//weights_l/weights.765-65.22.h5
# Epoch 766/2000
# 4216/4216 [==============================] - 11s 3ms/step - loss: 17.5368 - accuracy: 0.0000e+00 - val_loss: 64.1062 - val_accuracy: 0.0000e+00
#
# Epoch 00766: saving model to /gdrive/My Drive/ALGORITMOCORRECTO//weights_l/weights.766-64.11.h5
# Epoch 767/2000
# 4216/4216 [==============================] - 11s 3ms/step - loss: 17.5713 - accuracy: 0.0000e+00 - val_loss: 64.8618 - val_accuracy: 0.0000e+00
#
# Epoch 00767: saving model to /gdrive/My Drive/ALGORITMOCORRECTO//weights_l/weights.767-64.86.h5
# Epoch 768/2000
# 4216/4216 [==============================] - 11s 3ms/step - loss: 17.5501 - accuracy: 0.0000e+00 - val_loss: 63.3761 - val_accuracy: 0.0000e+00
#
# Epoch 00768: saving model to /gdrive/My Drive/ALGORITMOCORRECTO//weights_l/weights.768-63.38.h5
# Epoch 769/2000
# 4216/4216 [==============================] - 11s 3ms/step - loss: 17.5718 - accuracy: 0.0000e+00 - val_loss: 63.7051 - val_accuracy: 0.0000e+00
#
# Epoch 00769: saving model to /gdrive/My Drive/ALGORITMOCORRECTO//weights_l/weights.769-63.71.h5
# Epoch 770/2000
# 4216/4216 [==============================] - 11s 3ms/step - loss: 17.5452 - accuracy: 0.0000e+00 - val_loss: 64.6267 - val_accuracy: 0.0000e+00
#
# Epoch 00770: saving model to /gdrive/My Drive/ALGORITMOCORRECTO//weights_l/weights.770-64.63.h5
# Epoch 771/2000
# 4216/4216 [==============================] - 11s 3ms/step - loss: 17.5387 - accuracy: 0.0000e+00 - val_loss: 63.8279 - val_accuracy: 0.0000e+00
#
# Epoch 00771: saving model to /gdrive/My Drive/ALGORITMOCORRECTO//weights_l/weights.771-63.83.h5
# Epoch 772/2000
# 4216/4216 [==============================] - 12s 3ms/step - loss: 17.5833 - accuracy: 0.0000e+00 - val_loss: 62.8513 - val_accuracy: 0.0000e+00
#
# Epoch 00772: saving model to /gdrive/My Drive/ALGORITMOCORRECTO//weights_l/weights.772-62.85.h5
# Epoch 773/2000
# 4216/4216 [==============================] - 11s 3ms/step - loss: 17.5489 - accuracy: 0.0000e+00 - val_loss: 64.2211 - val_accuracy: 0.0000e+00
#
# Epoch 00773: saving model to /gdrive/My Drive/ALGORITMOCORRECTO//weights_l/weights.773-64.22.h5
# Epoch 774/2000
# 4216/4216 [==============================] - 11s 3ms/step - loss: 17.5574 - accuracy: 0.0000e+00 - val_loss: 64.0591 - val_accuracy: 0.0000e+00
#
# Epoch 00774: saving model to /gdrive/My Drive/ALGORITMOCORRECTO//weights_l/weights.774-64.06.h5
# Epoch 775/2000
# 4216/4216 [==============================] - 11s 3ms/step - loss: 17.5631 - accuracy: 0.0000e+00 - val_loss: 68.5278 - val_accuracy: 0.0000e+00
#
# Epoch 00775: saving model to /gdrive/My Drive/ALGORITMOCORRECTO//weights_l/weights.775-68.53.h5
# Epoch 776/2000
# 4216/4216 [==============================] - 11s 3ms/step - loss: 17.5693 - accuracy: 0.0000e+00 - val_loss: 64.5783 - val_accuracy: 0.0000e+00
#
# Epoch 00776: saving model to /gdrive/My Drive/ALGORITMOCORRECTO//weights_l/weights.776-64.58.h5
# Epoch 777/2000
# 4216/4216 [==============================] - 11s 3ms/step - loss: 17.5553 - accuracy: 0.0000e+00 - val_loss: 68.1753 - val_accuracy: 0.0000e+00
#
# Epoch 00777: saving model to /gdrive/My Drive/ALGORITMOCORRECTO//weights_l/weights.777-68.18.h5
# Epoch 778/2000
# 4216/4216 [==============================] - 11s 3ms/step - loss: 17.5619 - accuracy: 0.0000e+00 - val_loss: 63.9594 - val_accuracy: 0.0000e+00
#
# Epoch 00778: saving model to /gdrive/My Drive/ALGORITMOCORRECTO//weights_l/weights.778-63.96.h5
# Epoch 779/2000
# 4216/4216 [==============================] - 11s 3ms/step - loss: 17.6268 - accuracy: 0.0000e+00 - val_loss: 64.4959 - val_accuracy: 0.0000e+00
#
# Epoch 00779: saving model to /gdrive/My Drive/ALGORITMOCORRECTO//weights_l/weights.779-64.50.h5
# Epoch 780/2000
# 4216/4216 [==============================] - 11s 3ms/step - loss: 17.5553 - accuracy: 0.0000e+00 - val_loss: 64.2057 - val_accuracy: 0.0000e+00
#
# Epoch 00780: saving model to /gdrive/My Drive/ALGORITMOCORRECTO//weights_l/weights.780-64.21.h5
# Epoch 781/2000
# 4216/4216 [==============================] - 11s 3ms/step - loss: 17.5375 - accuracy: 0.0000e+00 - val_loss: 65.2453 - val_accuracy: 0.0000e+00
#
# Epoch 00781: saving model to /gdrive/My Drive/ALGORITMOCORRECTO//weights_l/weights.781-65.25.h5
# Epoch 782/2000
# 4216/4216 [==============================] - 11s 3ms/step - loss: 17.6046 - accuracy: 0.0000e+00 - val_loss: 63.8543 - val_accuracy: 0.0000e+00
#
# Epoch 00782: saving model to /gdrive/My Drive/ALGORITMOCORRECTO//weights_l/weights.782-63.85.h5
# Epoch 783/2000
# 4216/4216 [==============================] - 11s 3ms/step - loss: 17.5313 - accuracy: 0.0000e+00 - val_loss: 65.2123 - val_accuracy: 0.0000e+00
#
# Epoch 00783: saving model to /gdrive/My Drive/ALGORITMOCORRECTO//weights_l/weights.783-65.21.h5
# Epoch 784/2000
# 4216/4216 [==============================] - 11s 3ms/step - loss: 17.5317 - accuracy: 0.0000e+00 - val_loss: 64.5866 - val_accuracy: 0.0000e+00
#
# Epoch 00784: saving model to /gdrive/My Drive/ALGORITMOCORRECTO//weights_l/weights.784-64.59.h5
# Epoch 785/2000
# 4216/4216 [==============================] - 11s 3ms/step - loss: 17.5605 - accuracy: 0.0000e+00 - val_loss: 63.7857 - val_accuracy: 0.0000e+00
#
# Epoch 00785: saving model to /gdrive/My Drive/ALGORITMOCORRECTO//weights_l/weights.785-63.79.h5
# Epoch 786/2000
# 4216/4216 [==============================] - 11s 3ms/step - loss: 17.5439 - accuracy: 0.0000e+00 - val_loss: 63.9064 - val_accuracy: 0.0000e+00
#
# Epoch 00786: saving model to /gdrive/My Drive/ALGORITMOCORRECTO//weights_l/weights.786-63.91.h5
# Epoch 787/2000
# 4216/4216 [==============================] - 11s 3ms/step - loss: 17.5303 - accuracy: 0.0000e+00 - val_loss: 64.3769 - val_accuracy: 0.0000e+00
#
# Epoch 00787: saving model to /gdrive/My Drive/ALGORITMOCORRECTO//weights_l/weights.787-64.38.h5
# Epoch 788/2000
# 4216/4216 [==============================] - 11s 3ms/step - loss: 17.5384 - accuracy: 0.0000e+00 - val_loss: 63.4835 - val_accuracy: 0.0000e+00
#
# Epoch 00788: saving model to /gdrive/My Drive/ALGORITMOCORRECTO//weights_l/weights.788-63.48.h5
# Epoch 789/2000
# 4216/4216 [==============================] - 11s 3ms/step - loss: 17.5747 - accuracy: 0.0000e+00 - val_loss: 64.5593 - val_accuracy: 0.0000e+00
#
# Epoch 00789: saving model to /gdrive/My Drive/ALGORITMOCORRECTO//weights_l/weights.789-64.56.h5
# Epoch 790/2000
# 4216/4216 [==============================] - 11s 3ms/step - loss: 17.5265 - accuracy: 0.0000e+00 - val_loss: 62.8262 - val_accuracy: 0.0000e+00
#
# Epoch 00790: saving model to /gdrive/My Drive/ALGORITMOCORRECTO//weights_l/weights.790-62.83.h5
# Epoch 791/2000
# 4216/4216 [==============================] - 11s 3ms/step - loss: 17.5625 - accuracy: 0.0000e+00 - val_loss: 64.8090 - val_accuracy: 0.0000e+00
#
# Epoch 00791: saving model to /gdrive/My Drive/ALGORITMOCORRECTO//weights_l/weights.791-64.81.h5
# Epoch 792/2000
# 4216/4216 [==============================] - 11s 3ms/step - loss: 17.5487 - accuracy: 0.0000e+00 - val_loss: 64.3558 - val_accuracy: 0.0000e+00
#
# Epoch 00792: saving model to /gdrive/My Drive/ALGORITMOCORRECTO//weights_l/weights.792-64.36.h5
# Epoch 793/2000
# 4216/4216 [==============================] - 11s 3ms/step - loss: 17.5345 - accuracy: 0.0000e+00 - val_loss: 65.0256 - val_accuracy: 0.0000e+00
#
# Epoch 00793: saving model to /gdrive/My Drive/ALGORITMOCORRECTO//weights_l/weights.793-65.03.h5
# Epoch 794/2000
# 4216/4216 [==============================] - 11s 3ms/step - loss: 17.5468 - accuracy: 0.0000e+00 - val_loss: 64.2956 - val_accuracy: 0.0000e+00
#
# Epoch 00794: saving model to /gdrive/My Drive/ALGORITMOCORRECTO//weights_l/weights.794-64.30.h5
# Epoch 795/2000
# 4216/4216 [==============================] - 11s 3ms/step - loss: 17.5753 - accuracy: 0.0000e+00 - val_loss: 64.3144 - val_accuracy: 0.0000e+00
#
# Epoch 00795: saving model to /gdrive/My Drive/ALGORITMOCORRECTO//weights_l/weights.795-64.31.h5
# Epoch 796/2000
# 4216/4216 [==============================] - 11s 3ms/step - loss: 17.5748 - accuracy: 0.0000e+00 - val_loss: 63.6413 - val_accuracy: 0.0000e+00
#
# Epoch 00796: saving model to /gdrive/My Drive/ALGORITMOCORRECTO//weights_l/weights.796-63.64.h5
# Epoch 797/2000
# 4216/4216 [==============================] - 11s 3ms/step - loss: 17.5341 - accuracy: 0.0000e+00 - val_loss: 64.8570 - val_accuracy: 0.0000e+00
#
# Epoch 00797: saving model to /gdrive/My Drive/ALGORITMOCORRECTO//weights_l/weights.797-64.86.h5
# Epoch 798/2000
# 4216/4216 [==============================] - 11s 3ms/step - loss: 17.5410 - accuracy: 0.0000e+00 - val_loss: 65.8402 - val_accuracy: 0.0000e+00
#
# Epoch 00798: saving model to /gdrive/My Drive/ALGORITMOCORRECTO//weights_l/weights.798-65.84.h5
# Epoch 799/2000
# 4216/4216 [==============================] - 11s 3ms/step - loss: 17.5289 - accuracy: 0.0000e+00 - val_loss: 64.7592 - val_accuracy: 0.0000e+00
#
# Epoch 00799: saving model to /gdrive/My Drive/ALGORITMOCORRECTO//weights_l/weights.799-64.76.h5
# Epoch 800/2000
# 4216/4216 [==============================] - 12s 3ms/step - loss: 17.5210 - accuracy: 0.0000e+00 - val_loss: 63.5167 - val_accuracy: 0.0000e+00
#
# Epoch 00800: saving model to /gdrive/My Drive/ALGORITMOCORRECTO//weights_l/weights.800-63.52.h5
# Epoch 801/2000
# 4216/4216 [==============================] - 11s 3ms/step - loss: 17.5265 - accuracy: 0.0000e+00 - val_loss: 63.6289 - val_accuracy: 0.0000e+00
#
# Epoch 00801: saving model to /gdrive/My Drive/ALGORITMOCORRECTO//weights_l/weights.801-63.63.h5
# Epoch 802/2000
# 4216/4216 [==============================] - 11s 3ms/step - loss: 17.5368 - accuracy: 0.0000e+00 - val_loss: 63.6606 - val_accuracy: 0.0000e+00
#
# Epoch 00802: saving model to /gdrive/My Drive/ALGORITMOCORRECTO//weights_l/weights.802-63.66.h5
# Epoch 803/2000
# 4216/4216 [==============================] - 11s 3ms/step - loss: 17.5910 - accuracy: 0.0000e+00 - val_loss: 64.0332 - val_accuracy: 0.0000e+00
#
# Epoch 00803: saving model to /gdrive/My Drive/ALGORITMOCORRECTO//weights_l/weights.803-64.03.h5
# Epoch 804/2000
# 4216/4216 [==============================] - 11s 3ms/step - loss: 17.5685 - accuracy: 0.0000e+00 - val_loss: 68.3623 - val_accuracy: 0.0000e+00
#
# Epoch 00804: saving model to /gdrive/My Drive/ALGORITMOCORRECTO//weights_l/weights.804-68.36.h5
# Epoch 805/2000
# 4216/4216 [==============================] - 11s 3ms/step - loss: 17.5513 - accuracy: 0.0000e+00 - val_loss: 64.7585 - val_accuracy: 0.0000e+00
#
# Epoch 00805: saving model to /gdrive/My Drive/ALGORITMOCORRECTO//weights_l/weights.805-64.76.h5
# Epoch 806/2000
# 4216/4216 [==============================] - 11s 3ms/step - loss: 17.5118 - accuracy: 0.0000e+00 - val_loss: 68.0699 - val_accuracy: 0.0000e+00
#
# Epoch 00806: saving model to /gdrive/My Drive/ALGORITMOCORRECTO//weights_l/weights.806-68.07.h5
# Epoch 807/2000
# 4216/4216 [==============================] - 11s 3ms/step - loss: 17.5659 - accuracy: 0.0000e+00 - val_loss: 64.0923 - val_accuracy: 0.0000e+00
#
# Epoch 00807: saving model to /gdrive/My Drive/ALGORITMOCORRECTO//weights_l/weights.807-64.09.h5
# Epoch 808/2000
# 4216/4216 [==============================] - 11s 3ms/step - loss: 17.5096 - accuracy: 0.0000e+00 - val_loss: 67.5443 - val_accuracy: 0.0000e+00
#
# Epoch 00808: saving model to /gdrive/My Drive/ALGORITMOCORRECTO//weights_l/weights.808-67.54.h5
# Epoch 809/2000
# 4216/4216 [==============================] - 11s 3ms/step - loss: 17.5255 - accuracy: 0.0000e+00 - val_loss: 62.4935 - val_accuracy: 0.0000e+00
#
# Epoch 00809: saving model to /gdrive/My Drive/ALGORITMOCORRECTO//weights_l/weights.809-62.49.h5
# Epoch 810/2000
# 4216/4216 [==============================] - 11s 3ms/step - loss: 17.5265 - accuracy: 0.0000e+00 - val_loss: 68.1638 - val_accuracy: 0.0000e+00
#
# Epoch 00810: saving model to /gdrive/My Drive/ALGORITMOCORRECTO//weights_l/weights.810-68.16.h5
# Epoch 811/2000
# 4216/4216 [==============================] - 11s 3ms/step - loss: 17.5325 - accuracy: 0.0000e+00 - val_loss: 66.5645 - val_accuracy: 0.0000e+00
#
# Epoch 00811: saving model to /gdrive/My Drive/ALGORITMOCORRECTO//weights_l/weights.811-66.56.h5
# Epoch 812/2000
# 4216/4216 [==============================] - 11s 3ms/step - loss: 17.5172 - accuracy: 0.0000e+00 - val_loss: 64.1674 - val_accuracy: 0.0000e+00
#
# Epoch 00812: saving model to /gdrive/My Drive/ALGORITMOCORRECTO//weights_l/weights.812-64.17.h5
# Epoch 813/2000
# 4216/4216 [==============================] - 11s 3ms/step - loss: 17.5327 - accuracy: 0.0000e+00 - val_loss: 63.5511 - val_accuracy: 0.0000e+00
#
# Epoch 00813: saving model to /gdrive/My Drive/ALGORITMOCORRECTO//weights_l/weights.813-63.55.h5
# Epoch 814/2000
# 4216/4216 [==============================] - 11s 3ms/step - loss: 17.5233 - accuracy: 0.0000e+00 - val_loss: 64.8630 - val_accuracy: 0.0000e+00
#
# Epoch 00814: saving model to /gdrive/My Drive/ALGORITMOCORRECTO//weights_l/weights.814-64.86.h5
# Epoch 815/2000
# 4216/4216 [==============================] - 11s 3ms/step - loss: 17.5499 - accuracy: 0.0000e+00 - val_loss: 64.6302 - val_accuracy: 0.0000e+00
#
# Epoch 00815: saving model to /gdrive/My Drive/ALGORITMOCORRECTO//weights_l/weights.815-64.63.h5
# Epoch 816/2000
# 4216/4216 [==============================] - 11s 3ms/step - loss: 17.5711 - accuracy: 0.0000e+00 - val_loss: 64.9646 - val_accuracy: 0.0000e+00
#
# Epoch 00816: saving model to /gdrive/My Drive/ALGORITMOCORRECTO//weights_l/weights.816-64.96.h5
# Epoch 817/2000
# 4216/4216 [==============================] - 12s 3ms/step - loss: 17.5370 - accuracy: 0.0000e+00 - val_loss: 64.4027 - val_accuracy: 0.0000e+00
#
# Epoch 00817: saving model to /gdrive/My Drive/ALGORITMOCORRECTO//weights_l/weights.817-64.40.h5
# Epoch 818/2000
# 4216/4216 [==============================] - 12s 3ms/step - loss: 17.5128 - accuracy: 0.0000e+00 - val_loss: 64.0023 - val_accuracy: 0.0000e+00
#
# Epoch 00818: saving model to /gdrive/My Drive/ALGORITMOCORRECTO//weights_l/weights.818-64.00.h5
# Epoch 819/2000
# 4216/4216 [==============================] - 12s 3ms/step - loss: 17.5205 - accuracy: 0.0000e+00 - val_loss: 63.1061 - val_accuracy: 0.0000e+00
#
# Epoch 00819: saving model to /gdrive/My Drive/ALGORITMOCORRECTO//weights_l/weights.819-63.11.h5
# Epoch 820/2000
# 4216/4216 [==============================] - 12s 3ms/step - loss: 17.5368 - accuracy: 0.0000e+00 - val_loss: 65.1612 - val_accuracy: 0.0000e+00
#
# Epoch 00820: saving model to /gdrive/My Drive/ALGORITMOCORRECTO//weights_l/weights.820-65.16.h5
# Epoch 821/2000
# 4216/4216 [==============================] - 12s 3ms/step - loss: 17.5561 - accuracy: 0.0000e+00 - val_loss: 64.6349 - val_accuracy: 0.0000e+00
#
# Epoch 00821: saving model to /gdrive/My Drive/ALGORITMOCORRECTO//weights_l/weights.821-64.63.h5
# Epoch 822/2000
# 4216/4216 [==============================] - 12s 3ms/step - loss: 17.5698 - accuracy: 0.0000e+00 - val_loss: 64.1769 - val_accuracy: 0.0000e+00
#
# Epoch 00822: saving model to /gdrive/My Drive/ALGORITMOCORRECTO//weights_l/weights.822-64.18.h5
# Epoch 823/2000
# 4216/4216 [==============================] - 12s 3ms/step - loss: 17.5570 - accuracy: 0.0000e+00 - val_loss: 65.0015 - val_accuracy: 0.0000e+00
#
# Epoch 00823: saving model to /gdrive/My Drive/ALGORITMOCORRECTO//weights_l/weights.823-65.00.h5
# Epoch 824/2000
# 4216/4216 [==============================] - 11s 3ms/step - loss: 17.5274 - accuracy: 0.0000e+00 - val_loss: 63.3211 - val_accuracy: 0.0000e+00
#
# Epoch 00824: saving model to /gdrive/My Drive/ALGORITMOCORRECTO//weights_l/weights.824-63.32.h5
# Epoch 825/2000
# 4216/4216 [==============================] - 12s 3ms/step - loss: 17.5516 - accuracy: 0.0000e+00 - val_loss: 64.6309 - val_accuracy: 0.0000e+00
#
# Epoch 00825: saving model to /gdrive/My Drive/ALGORITMOCORRECTO//weights_l/weights.825-64.63.h5
# Epoch 826/2000
# 4216/4216 [==============================] - 12s 3ms/step - loss: 17.5387 - accuracy: 0.0000e+00 - val_loss: 65.3820 - val_accuracy: 0.0000e+00
#
# Epoch 00826: saving model to /gdrive/My Drive/ALGORITMOCORRECTO//weights_l/weights.826-65.38.h5
# Epoch 827/2000
# 4216/4216 [==============================] - 12s 3ms/step - loss: 17.5189 - accuracy: 0.0000e+00 - val_loss: 62.5511 - val_accuracy: 0.0000e+00
#
# Epoch 00827: saving model to /gdrive/My Drive/ALGORITMOCORRECTO//weights_l/weights.827-62.55.h5
# Epoch 828/2000
# 4216/4216 [==============================] - 12s 3ms/step - loss: 17.5250 - accuracy: 0.0000e+00 - val_loss: 63.9040 - val_accuracy: 0.0000e+00
#
# Epoch 00828: saving model to /gdrive/My Drive/ALGORITMOCORRECTO//weights_l/weights.828-63.90.h5
# Epoch 829/2000
# 4216/4216 [==============================] - 11s 3ms/step - loss: 17.5221 - accuracy: 0.0000e+00 - val_loss: 65.3719 - val_accuracy: 0.0000e+00
#
# Epoch 00829: saving model to /gdrive/My Drive/ALGORITMOCORRECTO//weights_l/weights.829-65.37.h5
# Epoch 830/2000
# 4216/4216 [==============================] - 11s 3ms/step - loss: 17.5190 - accuracy: 0.0000e+00 - val_loss: 63.1786 - val_accuracy: 0.0000e+00
#
# Epoch 00830: saving model to /gdrive/My Drive/ALGORITMOCORRECTO//weights_l/weights.830-63.18.h5
# Epoch 831/2000
# 4216/4216 [==============================] - 12s 3ms/step - loss: 17.5089 - accuracy: 0.0000e+00 - val_loss: 65.2329 - val_accuracy: 0.0000e+00
#
# Epoch 00831: saving model to /gdrive/My Drive/ALGORITMOCORRECTO//weights_l/weights.831-65.23.h5
# Epoch 832/2000
# 4216/4216 [==============================] - 11s 3ms/step - loss: 17.5446 - accuracy: 0.0000e+00 - val_loss: 64.7201 - val_accuracy: 0.0000e+00
#
# Epoch 00832: saving model to /gdrive/My Drive/ALGORITMOCORRECTO//weights_l/weights.832-64.72.h5
# Epoch 833/2000
# 4216/4216 [==============================] - 12s 3ms/step - loss: 17.4971 - accuracy: 0.0000e+00 - val_loss: 70.9464 - val_accuracy: 0.0000e+00
#
# Epoch 00833: saving model to /gdrive/My Drive/ALGORITMOCORRECTO//weights_l/weights.833-70.95.h5
# Epoch 834/2000
# 4216/4216 [==============================] - 11s 3ms/step - loss: 17.5452 - accuracy: 0.0000e+00 - val_loss: 63.9788 - val_accuracy: 0.0000e+00
#
# Epoch 00834: saving model to /gdrive/My Drive/ALGORITMOCORRECTO//weights_l/weights.834-63.98.h5
# Epoch 835/2000
# 4216/4216 [==============================] - 11s 3ms/step - loss: 17.5138 - accuracy: 0.0000e+00 - val_loss: 63.6386 - val_accuracy: 0.0000e+00
#
# Epoch 00835: saving model to /gdrive/My Drive/ALGORITMOCORRECTO//weights_l/weights.835-63.64.h5
# Epoch 836/2000
# 4216/4216 [==============================] - 11s 3ms/step - loss: 17.5138 - accuracy: 0.0000e+00 - val_loss: 64.3821 - val_accuracy: 0.0000e+00
#
# Epoch 00836: saving model to /gdrive/My Drive/ALGORITMOCORRECTO//weights_l/weights.836-64.38.h5
# Epoch 837/2000
# 4216/4216 [==============================] - 11s 3ms/step - loss: 17.5275 - accuracy: 0.0000e+00 - val_loss: 64.1575 - val_accuracy: 0.0000e+00
#
# Epoch 00837: saving model to /gdrive/My Drive/ALGORITMOCORRECTO//weights_l/weights.837-64.16.h5
# Epoch 838/2000
# 4216/4216 [==============================] - 11s 3ms/step - loss: 17.5052 - accuracy: 0.0000e+00 - val_loss: 64.7517 - val_accuracy: 0.0000e+00
#
# Epoch 00838: saving model to /gdrive/My Drive/ALGORITMOCORRECTO//weights_l/weights.838-64.75.h5
# Epoch 839/2000
# 4216/4216 [==============================] - 12s 3ms/step - loss: 17.5394 - accuracy: 0.0000e+00 - val_loss: 64.6448 - val_accuracy: 0.0000e+00
#
# Epoch 00839: saving model to /gdrive/My Drive/ALGORITMOCORRECTO//weights_l/weights.839-64.64.h5
# Epoch 840/2000
# 4216/4216 [==============================] - 12s 3ms/step - loss: 17.5175 - accuracy: 0.0000e+00 - val_loss: 61.3296 - val_accuracy: 0.0000e+00
#
# Epoch 00840: saving model to /gdrive/My Drive/ALGORITMOCORRECTO//weights_l/weights.840-61.33.h5
# Epoch 841/2000
# 4216/4216 [==============================] - 11s 3ms/step - loss: 17.5450 - accuracy: 0.0000e+00 - val_loss: 64.3201 - val_accuracy: 0.0000e+00
#
# Epoch 00841: saving model to /gdrive/My Drive/ALGORITMOCORRECTO//weights_l/weights.841-64.32.h5
# Epoch 842/2000
# 4216/4216 [==============================] - 12s 3ms/step - loss: 17.5147 - accuracy: 0.0000e+00 - val_loss: 62.7372 - val_accuracy: 0.0000e+00
#
# Epoch 00842: saving model to /gdrive/My Drive/ALGORITMOCORRECTO//weights_l/weights.842-62.74.h5
# Epoch 843/2000
# 4216/4216 [==============================] - 11s 3ms/step - loss: 17.5298 - accuracy: 0.0000e+00 - val_loss: 62.2582 - val_accuracy: 0.0000e+00
#
# Epoch 00843: saving model to /gdrive/My Drive/ALGORITMOCORRECTO//weights_l/weights.843-62.26.h5
# Epoch 844/2000
# 4216/4216 [==============================] - 11s 3ms/step - loss: 17.5684 - accuracy: 0.0000e+00 - val_loss: 64.1698 - val_accuracy: 0.0000e+00
#
# Epoch 00844: saving model to /gdrive/My Drive/ALGORITMOCORRECTO//weights_l/weights.844-64.17.h5
# Epoch 845/2000
# 4216/4216 [==============================] - 12s 3ms/step - loss: 17.5447 - accuracy: 0.0000e+00 - val_loss: 64.6350 - val_accuracy: 0.0000e+00
#
# Epoch 00845: saving model to /gdrive/My Drive/ALGORITMOCORRECTO//weights_l/weights.845-64.63.h5
# Epoch 846/2000
# 4216/4216 [==============================] - 12s 3ms/step - loss: 17.5245 - accuracy: 0.0000e+00 - val_loss: 62.0463 - val_accuracy: 0.0000e+00
#
# Epoch 00846: saving model to /gdrive/My Drive/ALGORITMOCORRECTO//weights_l/weights.846-62.05.h5
# Epoch 847/2000
# 4216/4216 [==============================] - 12s 3ms/step - loss: 17.5005 - accuracy: 0.0000e+00 - val_loss: 65.2136 - val_accuracy: 0.0000e+00
#
# Epoch 00847: saving model to /gdrive/My Drive/ALGORITMOCORRECTO//weights_l/weights.847-65.21.h5
# Epoch 848/2000
# 4216/4216 [==============================] - 12s 3ms/step - loss: 17.5025 - accuracy: 0.0000e+00 - val_loss: 64.9792 - val_accuracy: 0.0000e+00
#
# Epoch 00848: saving model to /gdrive/My Drive/ALGORITMOCORRECTO//weights_l/weights.848-64.98.h5
# Epoch 849/2000
# 4216/4216 [==============================] - 11s 3ms/step - loss: 17.5030 - accuracy: 0.0000e+00 - val_loss: 64.3658 - val_accuracy: 0.0000e+00
#
# Epoch 00849: saving model to /gdrive/My Drive/ALGORITMOCORRECTO//weights_l/weights.849-64.37.h5
# Epoch 850/2000
# 4216/4216 [==============================] - 12s 3ms/step - loss: 17.5215 - accuracy: 0.0000e+00 - val_loss: 63.9095 - val_accuracy: 0.0000e+00
#
# Epoch 00850: saving model to /gdrive/My Drive/ALGORITMOCORRECTO//weights_l/weights.850-63.91.h5
# Epoch 851/2000
# 4216/4216 [==============================] - 12s 3ms/step - loss: 17.5113 - accuracy: 0.0000e+00 - val_loss: 64.5497 - val_accuracy: 0.0000e+00
#
# Epoch 00851: saving model to /gdrive/My Drive/ALGORITMOCORRECTO//weights_l/weights.851-64.55.h5
# Epoch 852/2000
# 4216/4216 [==============================] - 11s 3ms/step - loss: 17.5177 - accuracy: 0.0000e+00 - val_loss: 64.4002 - val_accuracy: 0.0000e+00
#
# Epoch 00852: saving model to /gdrive/My Drive/ALGORITMOCORRECTO//weights_l/weights.852-64.40.h5
# Epoch 853/2000
# 4216/4216 [==============================] - 12s 3ms/step - loss: 17.5117 - accuracy: 0.0000e+00 - val_loss: 63.7481 - val_accuracy: 0.0000e+00
#
# Epoch 00853: saving model to /gdrive/My Drive/ALGORITMOCORRECTO//weights_l/weights.853-63.75.h5
# Epoch 854/2000
# 4216/4216 [==============================] - 12s 3ms/step - loss: 17.4930 - accuracy: 0.0000e+00 - val_loss: 63.8335 - val_accuracy: 0.0000e+00
#
# Epoch 00854: saving model to /gdrive/My Drive/ALGORITMOCORRECTO//weights_l/weights.854-63.83.h5
# Epoch 855/2000
# 4216/4216 [==============================] - 12s 3ms/step - loss: 17.5114 - accuracy: 0.0000e+00 - val_loss: 63.9985 - val_accuracy: 0.0000e+00
#
# Epoch 00855: saving model to /gdrive/My Drive/ALGORITMOCORRECTO//weights_l/weights.855-64.00.h5
# Epoch 856/2000
# 4216/4216 [==============================] - 12s 3ms/step - loss: 17.5205 - accuracy: 0.0000e+00 - val_loss: 64.2047 - val_accuracy: 0.0000e+00
#
# Epoch 00856: saving model to /gdrive/My Drive/ALGORITMOCORRECTO//weights_l/weights.856-64.20.h5
# Epoch 857/2000
# 4216/4216 [==============================] - 12s 3ms/step - loss: 17.4841 - accuracy: 0.0000e+00 - val_loss: 63.7547 - val_accuracy: 0.0000e+00
#
# Epoch 00857: saving model to /gdrive/My Drive/ALGORITMOCORRECTO//weights_l/weights.857-63.75.h5
# Epoch 858/2000
# 4216/4216 [==============================] - 12s 3ms/step - loss: 17.5180 - accuracy: 0.0000e+00 - val_loss: 64.0937 - val_accuracy: 0.0000e+00
#
# Epoch 00858: saving model to /gdrive/My Drive/ALGORITMOCORRECTO//weights_l/weights.858-64.09.h5
# Epoch 859/2000
# 4216/4216 [==============================] - 12s 3ms/step - loss: 17.5218 - accuracy: 0.0000e+00 - val_loss: 63.3556 - val_accuracy: 0.0000e+00
#
# Epoch 00859: saving model to /gdrive/My Drive/ALGORITMOCORRECTO//weights_l/weights.859-63.36.h5
# Epoch 860/2000
# 4216/4216 [==============================] - 12s 3ms/step - loss: 17.5274 - accuracy: 0.0000e+00 - val_loss: 63.1804 - val_accuracy: 0.0000e+00
#
# Epoch 00860: saving model to /gdrive/My Drive/ALGORITMOCORRECTO//weights_l/weights.860-63.18.h5
# Epoch 861/2000
# 4216/4216 [==============================] - 12s 3ms/step - loss: 17.5021 - accuracy: 0.0000e+00 - val_loss: 63.6359 - val_accuracy: 0.0000e+00
#
# Epoch 00861: saving model to /gdrive/My Drive/ALGORITMOCORRECTO//weights_l/weights.861-63.64.h5
# Epoch 862/2000
# 4216/4216 [==============================] - 12s 3ms/step - loss: 17.5060 - accuracy: 0.0000e+00 - val_loss: 64.4011 - val_accuracy: 0.0000e+00
#
# Epoch 00862: saving model to /gdrive/My Drive/ALGORITMOCORRECTO//weights_l/weights.862-64.40.h5
# Epoch 863/2000
# 4216/4216 [==============================] - 12s 3ms/step - loss: 17.4905 - accuracy: 0.0000e+00 - val_loss: 63.5201 - val_accuracy: 0.0000e+00
#
# Epoch 00863: saving model to /gdrive/My Drive/ALGORITMOCORRECTO//weights_l/weights.863-63.52.h5
# Epoch 864/2000
# 4216/4216 [==============================] - 12s 3ms/step - loss: 17.5469 - accuracy: 0.0000e+00 - val_loss: 62.9274 - val_accuracy: 0.0000e+00
#
# Epoch 00864: saving model to /gdrive/My Drive/ALGORITMOCORRECTO//weights_l/weights.864-62.93.h5
# Epoch 865/2000
# 4216/4216 [==============================] - 12s 3ms/step - loss: 17.5103 - accuracy: 0.0000e+00 - val_loss: 64.6890 - val_accuracy: 0.0000e+00
#
# Epoch 00865: saving model to /gdrive/My Drive/ALGORITMOCORRECTO//weights_l/weights.865-64.69.h5
# Epoch 866/2000
# 4216/4216 [==============================] - 12s 3ms/step - loss: 17.4976 - accuracy: 0.0000e+00 - val_loss: 65.0919 - val_accuracy: 0.0000e+00
#
# Epoch 00866: saving model to /gdrive/My Drive/ALGORITMOCORRECTO//weights_l/weights.866-65.09.h5
# Epoch 867/2000
# 4216/4216 [==============================] - 12s 3ms/step - loss: 17.4837 - accuracy: 0.0000e+00 - val_loss: 64.1669 - val_accuracy: 0.0000e+00
#
# Epoch 00867: saving model to /gdrive/My Drive/ALGORITMOCORRECTO//weights_l/weights.867-64.17.h5
# Epoch 868/2000
# 4216/4216 [==============================] - 12s 3ms/step - loss: 17.5091 - accuracy: 0.0000e+00 - val_loss: 63.4454 - val_accuracy: 0.0000e+00
#
# Epoch 00868: saving model to /gdrive/My Drive/ALGORITMOCORRECTO//weights_l/weights.868-63.45.h5
# Epoch 869/2000
# 4216/4216 [==============================] - 12s 3ms/step - loss: 17.5311 - accuracy: 0.0000e+00 - val_loss: 63.5845 - val_accuracy: 0.0000e+00
#
# Epoch 00869: saving model to /gdrive/My Drive/ALGORITMOCORRECTO//weights_l/weights.869-63.58.h5
# Epoch 870/2000
# 4216/4216 [==============================] - 12s 3ms/step - loss: 17.5294 - accuracy: 0.0000e+00 - val_loss: 64.4507 - val_accuracy: 0.0000e+00
#
# Epoch 00870: saving model to /gdrive/My Drive/ALGORITMOCORRECTO//weights_l/weights.870-64.45.h5
# Epoch 871/2000
# 4216/4216 [==============================] - 12s 3ms/step - loss: 17.5214 - accuracy: 0.0000e+00 - val_loss: 64.0425 - val_accuracy: 0.0000e+00
#
# Epoch 00871: saving model to /gdrive/My Drive/ALGORITMOCORRECTO//weights_l/weights.871-64.04.h5
# Epoch 872/2000
# 4216/4216 [==============================] - 12s 3ms/step - loss: 17.5234 - accuracy: 0.0000e+00 - val_loss: 64.2923 - val_accuracy: 0.0000e+00
#
# Epoch 00872: saving model to /gdrive/My Drive/ALGORITMOCORRECTO//weights_l/weights.872-64.29.h5
# Epoch 873/2000
# 4216/4216 [==============================] - 11s 3ms/step - loss: 17.5389 - accuracy: 0.0000e+00 - val_loss: 65.3683 - val_accuracy: 0.0000e+00
#
# Epoch 00873: saving model to /gdrive/My Drive/ALGORITMOCORRECTO//weights_l/weights.873-65.37.h5
# Epoch 874/2000
# 4216/4216 [==============================] - 11s 3ms/step - loss: 17.5172 - accuracy: 0.0000e+00 - val_loss: 67.9107 - val_accuracy: 0.0000e+00
#
# Epoch 00874: saving model to /gdrive/My Drive/ALGORITMOCORRECTO//weights_l/weights.874-67.91.h5
# Epoch 875/2000
# 4216/4216 [==============================] - 12s 3ms/step - loss: 17.5191 - accuracy: 0.0000e+00 - val_loss: 64.5875 - val_accuracy: 0.0000e+00
#
# Epoch 00875: saving model to /gdrive/My Drive/ALGORITMOCORRECTO//weights_l/weights.875-64.59.h5
# Epoch 876/2000
# 4216/4216 [==============================] - 12s 3ms/step - loss: 17.4979 - accuracy: 0.0000e+00 - val_loss: 63.8185 - val_accuracy: 0.0000e+00
#
# Epoch 00876: saving model to /gdrive/My Drive/ALGORITMOCORRECTO//weights_l/weights.876-63.82.h5
# Epoch 877/2000
# 4216/4216 [==============================] - 12s 3ms/step - loss: 17.5098 - accuracy: 0.0000e+00 - val_loss: 63.4335 - val_accuracy: 0.0000e+00
#
# Epoch 00877: saving model to /gdrive/My Drive/ALGORITMOCORRECTO//weights_l/weights.877-63.43.h5
# Epoch 878/2000
# 4216/4216 [==============================] - 12s 3ms/step - loss: 17.5055 - accuracy: 0.0000e+00 - val_loss: 63.3505 - val_accuracy: 0.0000e+00
#
# Epoch 00878: saving model to /gdrive/My Drive/ALGORITMOCORRECTO//weights_l/weights.878-63.35.h5
# Epoch 879/2000
# 4216/4216 [==============================] - 12s 3ms/step - loss: 17.5196 - accuracy: 0.0000e+00 - val_loss: 64.1986 - val_accuracy: 0.0000e+00
#
# Epoch 00879: saving model to /gdrive/My Drive/ALGORITMOCORRECTO//weights_l/weights.879-64.20.h5
# Epoch 880/2000
# 4216/4216 [==============================] - 12s 3ms/step - loss: 17.5200 - accuracy: 0.0000e+00 - val_loss: 63.4111 - val_accuracy: 0.0000e+00
#
# Epoch 00880: saving model to /gdrive/My Drive/ALGORITMOCORRECTO//weights_l/weights.880-63.41.h5
# Epoch 881/2000
# 4216/4216 [==============================] - 12s 3ms/step - loss: 17.5069 - accuracy: 0.0000e+00 - val_loss: 64.5792 - val_accuracy: 0.0000e+00
#
# Epoch 00881: saving model to /gdrive/My Drive/ALGORITMOCORRECTO//weights_l/weights.881-64.58.h5
# Epoch 882/2000
# 4216/4216 [==============================] - 12s 3ms/step - loss: 17.5436 - accuracy: 0.0000e+00 - val_loss: 64.4702 - val_accuracy: 0.0000e+00
#
# Epoch 00882: saving model to /gdrive/My Drive/ALGORITMOCORRECTO//weights_l/weights.882-64.47.h5
# Epoch 883/2000
# 4216/4216 [==============================] - 12s 3ms/step - loss: 17.4867 - accuracy: 0.0000e+00 - val_loss: 63.7081 - val_accuracy: 0.0000e+00
#
# Epoch 00883: saving model to /gdrive/My Drive/ALGORITMOCORRECTO//weights_l/weights.883-63.71.h5
# Epoch 884/2000
# 4216/4216 [==============================] - 12s 3ms/step - loss: 17.5256 - accuracy: 0.0000e+00 - val_loss: 64.2424 - val_accuracy: 0.0000e+00
#
# Epoch 00884: saving model to /gdrive/My Drive/ALGORITMOCORRECTO//weights_l/weights.884-64.24.h5
# Epoch 885/2000
# 4216/4216 [==============================] - 12s 3ms/step - loss: 17.5199 - accuracy: 0.0000e+00 - val_loss: 64.1178 - val_accuracy: 0.0000e+00
#
# Epoch 00885: saving model to /gdrive/My Drive/ALGORITMOCORRECTO//weights_l/weights.885-64.12.h5
# Epoch 886/2000
# 4216/4216 [==============================] - 12s 3ms/step - loss: 17.5417 - accuracy: 0.0000e+00 - val_loss: 63.7108 - val_accuracy: 0.0000e+00
#
# Epoch 00886: saving model to /gdrive/My Drive/ALGORITMOCORRECTO//weights_l/weights.886-63.71.h5
# Epoch 887/2000
# 4216/4216 [==============================] - 12s 3ms/step - loss: 17.4880 - accuracy: 0.0000e+00 - val_loss: 63.9626 - val_accuracy: 0.0000e+00
#
# Epoch 00887: saving model to /gdrive/My Drive/ALGORITMOCORRECTO//weights_l/weights.887-63.96.h5
# Epoch 888/2000
# 4216/4216 [==============================] - 12s 3ms/step - loss: 17.5153 - accuracy: 0.0000e+00 - val_loss: 64.5875 - val_accuracy: 0.0000e+00
#
# Epoch 00888: saving model to /gdrive/My Drive/ALGORITMOCORRECTO//weights_l/weights.888-64.59.h5
# Epoch 889/2000
# 4216/4216 [==============================] - 12s 3ms/step - loss: 17.5332 - accuracy: 0.0000e+00 - val_loss: 64.8257 - val_accuracy: 0.0000e+00
#
# Epoch 00889: saving model to /gdrive/My Drive/ALGORITMOCORRECTO//weights_l/weights.889-64.83.h5
# Epoch 890/2000
# 4216/4216 [==============================] - 12s 3ms/step - loss: 17.4915 - accuracy: 0.0000e+00 - val_loss: 64.0156 - val_accuracy: 0.0000e+00
#
# Epoch 00890: saving model to /gdrive/My Drive/ALGORITMOCORRECTO//weights_l/weights.890-64.02.h5
# Epoch 891/2000
# 4216/4216 [==============================] - 12s 3ms/step - loss: 17.4663 - accuracy: 0.0000e+00 - val_loss: 63.0946 - val_accuracy: 0.0000e+00
#
# Epoch 00891: saving model to /gdrive/My Drive/ALGORITMOCORRECTO//weights_l/weights.891-63.09.h5
# Epoch 892/2000
# 4216/4216 [==============================] - 12s 3ms/step - loss: 17.5218 - accuracy: 0.0000e+00 - val_loss: 64.2510 - val_accuracy: 0.0000e+00
#
# Epoch 00892: saving model to /gdrive/My Drive/ALGORITMOCORRECTO//weights_l/weights.892-64.25.h5
# Epoch 893/2000
# 4216/4216 [==============================] - 12s 3ms/step - loss: 17.5185 - accuracy: 0.0000e+00 - val_loss: 64.1647 - val_accuracy: 0.0000e+00
#
# Epoch 00893: saving model to /gdrive/My Drive/ALGORITMOCORRECTO//weights_l/weights.893-64.16.h5
# Epoch 894/2000
# 4216/4216 [==============================] - 12s 3ms/step - loss: 17.4980 - accuracy: 0.0000e+00 - val_loss: 64.2015 - val_accuracy: 0.0000e+00
#
# Epoch 00894: saving model to /gdrive/My Drive/ALGORITMOCORRECTO//weights_l/weights.894-64.20.h5
# Epoch 895/2000
# 4216/4216 [==============================] - 12s 3ms/step - loss: 17.5211 - accuracy: 0.0000e+00 - val_loss: 63.6380 - val_accuracy: 0.0000e+00
#
# Epoch 00895: saving model to /gdrive/My Drive/ALGORITMOCORRECTO//weights_l/weights.895-63.64.h5
# Epoch 896/2000
# 4216/4216 [==============================] - 12s 3ms/step - loss: 17.4694 - accuracy: 0.0000e+00 - val_loss: 63.7937 - val_accuracy: 0.0000e+00
#
# Epoch 00896: saving model to /gdrive/My Drive/ALGORITMOCORRECTO//weights_l/weights.896-63.79.h5
# Epoch 897/2000
# 4216/4216 [==============================] - 12s 3ms/step - loss: 17.4809 - accuracy: 0.0000e+00 - val_loss: 64.0903 - val_accuracy: 0.0000e+00
#
# Epoch 00897: saving model to /gdrive/My Drive/ALGORITMOCORRECTO//weights_l/weights.897-64.09.h5
# Epoch 898/2000
# 4216/4216 [==============================] - 12s 3ms/step - loss: 17.4738 - accuracy: 0.0000e+00 - val_loss: 64.3286 - val_accuracy: 0.0000e+00
#
# Epoch 00898: saving model to /gdrive/My Drive/ALGORITMOCORRECTO//weights_l/weights.898-64.33.h5
# Epoch 899/2000
# 4216/4216 [==============================] - 12s 3ms/step - loss: 17.5021 - accuracy: 0.0000e+00 - val_loss: 63.9923 - val_accuracy: 0.0000e+00
#
# Epoch 00899: saving model to /gdrive/My Drive/ALGORITMOCORRECTO//weights_l/weights.899-63.99.h5
# Epoch 900/2000
# 4216/4216 [==============================] - 12s 3ms/step - loss: 17.5054 - accuracy: 0.0000e+00 - val_loss: 63.3735 - val_accuracy: 0.0000e+00
#
# Epoch 00900: saving model to /gdrive/My Drive/ALGORITMOCORRECTO//weights_l/weights.900-63.37.h5
# Epoch 901/2000
# 4216/4216 [==============================] - 12s 3ms/step - loss: 17.4786 - accuracy: 0.0000e+00 - val_loss: 65.0740 - val_accuracy: 0.0000e+00
#
# Epoch 00901: saving model to /gdrive/My Drive/ALGORITMOCORRECTO//weights_l/weights.901-65.07.h5
# Epoch 902/2000
# 4216/4216 [==============================] - 12s 3ms/step - loss: 17.5124 - accuracy: 0.0000e+00 - val_loss: 63.0575 - val_accuracy: 0.0000e+00
#
# Epoch 00902: saving model to /gdrive/My Drive/ALGORITMOCORRECTO//weights_l/weights.902-63.06.h5
# Epoch 903/2000
# 4216/4216 [==============================] - 12s 3ms/step - loss: 17.5115 - accuracy: 0.0000e+00 - val_loss: 64.8209 - val_accuracy: 0.0000e+00
#
# Epoch 00903: saving model to /gdrive/My Drive/ALGORITMOCORRECTO//weights_l/weights.903-64.82.h5
# Epoch 904/2000
# 4216/4216 [==============================] - 12s 3ms/step - loss: 17.5220 - accuracy: 0.0000e+00 - val_loss: 64.9744 - val_accuracy: 0.0000e+00
#
# Epoch 00904: saving model to /gdrive/My Drive/ALGORITMOCORRECTO//weights_l/weights.904-64.97.h5
# Epoch 905/2000
# 4216/4216 [==============================] - 12s 3ms/step - loss: 17.4736 - accuracy: 0.0000e+00 - val_loss: 64.4612 - val_accuracy: 0.0000e+00
#
# Epoch 00905: saving model to /gdrive/My Drive/ALGORITMOCORRECTO//weights_l/weights.905-64.46.h5
# Epoch 906/2000
# 4216/4216 [==============================] - 12s 3ms/step - loss: 17.4945 - accuracy: 0.0000e+00 - val_loss: 65.0651 - val_accuracy: 0.0000e+00
#
# Epoch 00906: saving model to /gdrive/My Drive/ALGORITMOCORRECTO//weights_l/weights.906-65.07.h5
# Epoch 907/2000
# 4216/4216 [==============================] - 12s 3ms/step - loss: 17.4922 - accuracy: 0.0000e+00 - val_loss: 64.6550 - val_accuracy: 0.0000e+00
#
# Epoch 00907: saving model to /gdrive/My Drive/ALGORITMOCORRECTO//weights_l/weights.907-64.66.h5
# Epoch 908/2000
# 4216/4216 [==============================] - 12s 3ms/step - loss: 17.4853 - accuracy: 0.0000e+00 - val_loss: 69.9338 - val_accuracy: 0.0000e+00
#
# Epoch 00908: saving model to /gdrive/My Drive/ALGORITMOCORRECTO//weights_l/weights.908-69.93.h5
# Epoch 909/2000
# 4216/4216 [==============================] - 12s 3ms/step - loss: 17.4808 - accuracy: 0.0000e+00 - val_loss: 63.8456 - val_accuracy: 0.0000e+00
#
# Epoch 00909: saving model to /gdrive/My Drive/ALGORITMOCORRECTO//weights_l/weights.909-63.85.h5
# Epoch 910/2000
# 4216/4216 [==============================] - 12s 3ms/step - loss: 17.4863 - accuracy: 0.0000e+00 - val_loss: 61.8132 - val_accuracy: 0.0000e+00
#
# Epoch 00910: saving model to /gdrive/My Drive/ALGORITMOCORRECTO//weights_l/weights.910-61.81.h5
# Epoch 911/2000
# 4216/4216 [==============================] - 12s 3ms/step - loss: 17.4876 - accuracy: 0.0000e+00 - val_loss: 64.1750 - val_accuracy: 0.0000e+00
#
# Epoch 00911: saving model to /gdrive/My Drive/ALGORITMOCORRECTO//weights_l/weights.911-64.17.h5
# Epoch 912/2000
# 4216/4216 [==============================] - 12s 3ms/step - loss: 17.4796 - accuracy: 0.0000e+00 - val_loss: 63.7495 - val_accuracy: 0.0000e+00
#
# Epoch 00912: saving model to /gdrive/My Drive/ALGORITMOCORRECTO//weights_l/weights.912-63.75.h5
# Epoch 913/2000
# 4216/4216 [==============================] - 12s 3ms/step - loss: 17.4884 - accuracy: 0.0000e+00 - val_loss: 65.8654 - val_accuracy: 0.0000e+00
#
# Epoch 00913: saving model to /gdrive/My Drive/ALGORITMOCORRECTO//weights_l/weights.913-65.87.h5
# Epoch 914/2000
# 4216/4216 [==============================] - 12s 3ms/step - loss: 17.4729 - accuracy: 0.0000e+00 - val_loss: 65.0066 - val_accuracy: 0.0000e+00
#
# Epoch 00914: saving model to /gdrive/My Drive/ALGORITMOCORRECTO//weights_l/weights.914-65.01.h5
# Epoch 915/2000
# 4216/4216 [==============================] - 12s 3ms/step - loss: 17.4891 - accuracy: 0.0000e+00 - val_loss: 64.4971 - val_accuracy: 0.0000e+00
#
# Epoch 00915: saving model to /gdrive/My Drive/ALGORITMOCORRECTO//weights_l/weights.915-64.50.h5
# Epoch 916/2000
# 4216/4216 [==============================] - 12s 3ms/step - loss: 17.5059 - accuracy: 0.0000e+00 - val_loss: 64.7416 - val_accuracy: 0.0000e+00
#
# Epoch 00916: saving model to /gdrive/My Drive/ALGORITMOCORRECTO//weights_l/weights.916-64.74.h5
# Epoch 917/2000
# 4216/4216 [==============================] - 12s 3ms/step - loss: 17.5093 - accuracy: 0.0000e+00 - val_loss: 64.2666 - val_accuracy: 0.0000e+00
#
# Epoch 00917: saving model to /gdrive/My Drive/ALGORITMOCORRECTO//weights_l/weights.917-64.27.h5
# Epoch 918/2000
# 4216/4216 [==============================] - 12s 3ms/step - loss: 17.4737 - accuracy: 0.0000e+00 - val_loss: 68.0551 - val_accuracy: 0.0000e+00
#
# Epoch 00918: saving model to /gdrive/My Drive/ALGORITMOCORRECTO//weights_l/weights.918-68.06.h5
# Epoch 919/2000
# 4216/4216 [==============================] - 12s 3ms/step - loss: 17.5106 - accuracy: 0.0000e+00 - val_loss: 64.5607 - val_accuracy: 0.0000e+00
#
# Epoch 00919: saving model to /gdrive/My Drive/ALGORITMOCORRECTO//weights_l/weights.919-64.56.h5
# Epoch 920/2000
# 4216/4216 [==============================] - 12s 3ms/step - loss: 17.4941 - accuracy: 0.0000e+00 - val_loss: 64.6577 - val_accuracy: 0.0000e+00
#
# Epoch 00920: saving model to /gdrive/My Drive/ALGORITMOCORRECTO//weights_l/weights.920-64.66.h5
# Epoch 921/2000
# 4216/4216 [==============================] - 12s 3ms/step - loss: 17.5158 - accuracy: 0.0000e+00 - val_loss: 63.5961 - val_accuracy: 0.0000e+00
#
# Epoch 00921: saving model to /gdrive/My Drive/ALGORITMOCORRECTO//weights_l/weights.921-63.60.h5
# Epoch 922/2000
# 4216/4216 [==============================] - 12s 3ms/step - loss: 17.4908 - accuracy: 0.0000e+00 - val_loss: 64.1149 - val_accuracy: 0.0000e+00
#
# Epoch 00922: saving model to /gdrive/My Drive/ALGORITMOCORRECTO//weights_l/weights.922-64.11.h5
# Epoch 923/2000
# 4216/4216 [==============================] - 12s 3ms/step - loss: 17.4734 - accuracy: 0.0000e+00 - val_loss: 63.9354 - val_accuracy: 0.0000e+00
#
# Epoch 00923: saving model to /gdrive/My Drive/ALGORITMOCORRECTO//weights_l/weights.923-63.94.h5
# Epoch 924/2000
# 4216/4216 [==============================] - 12s 3ms/step - loss: 17.4835 - accuracy: 0.0000e+00 - val_loss: 62.8775 - val_accuracy: 0.0000e+00
#
# Epoch 00924: saving model to /gdrive/My Drive/ALGORITMOCORRECTO//weights_l/weights.924-62.88.h5
# Epoch 925/2000
# 4216/4216 [==============================] - 12s 3ms/step - loss: 17.5071 - accuracy: 0.0000e+00 - val_loss: 68.7278 - val_accuracy: 0.0000e+00
#
# Epoch 00925: saving model to /gdrive/My Drive/ALGORITMOCORRECTO//weights_l/weights.925-68.73.h5
# Epoch 926/2000
# 4216/4216 [==============================] - 12s 3ms/step - loss: 17.4967 - accuracy: 0.0000e+00 - val_loss: 65.5873 - val_accuracy: 0.0000e+00
#
# Epoch 00926: saving model to /gdrive/My Drive/ALGORITMOCORRECTO//weights_l/weights.926-65.59.h5
# Epoch 927/2000
# 4216/4216 [==============================] - 12s 3ms/step - loss: 17.4975 - accuracy: 0.0000e+00 - val_loss: 64.8557 - val_accuracy: 0.0000e+00
#
# Epoch 00927: saving model to /gdrive/My Drive/ALGORITMOCORRECTO//weights_l/weights.927-64.86.h5
# Epoch 928/2000
# 4216/4216 [==============================] - 12s 3ms/step - loss: 17.4944 - accuracy: 0.0000e+00 - val_loss: 64.4408 - val_accuracy: 0.0000e+00
#
# Epoch 00928: saving model to /gdrive/My Drive/ALGORITMOCORRECTO//weights_l/weights.928-64.44.h5
# Epoch 929/2000
# 4216/4216 [==============================] - 12s 3ms/step - loss: 17.5104 - accuracy: 0.0000e+00 - val_loss: 64.2265 - val_accuracy: 0.0000e+00
#
# Epoch 00929: saving model to /gdrive/My Drive/ALGORITMOCORRECTO//weights_l/weights.929-64.23.h5
# Epoch 930/2000
# 4216/4216 [==============================] - 12s 3ms/step - loss: 17.5050 - accuracy: 0.0000e+00 - val_loss: 67.1714 - val_accuracy: 0.0000e+00
#
# Epoch 00930: saving model to /gdrive/My Drive/ALGORITMOCORRECTO//weights_l/weights.930-67.17.h5
# Epoch 931/2000
# 4216/4216 [==============================] - 12s 3ms/step - loss: 17.4961 - accuracy: 0.0000e+00 - val_loss: 63.5164 - val_accuracy: 0.0000e+00
#
# Epoch 00931: saving model to /gdrive/My Drive/ALGORITMOCORRECTO//weights_l/weights.931-63.52.h5
# Epoch 932/2000
# 4216/4216 [==============================] - 12s 3ms/step - loss: 17.4749 - accuracy: 0.0000e+00 - val_loss: 65.9416 - val_accuracy: 0.0000e+00
#
# Epoch 00932: saving model to /gdrive/My Drive/ALGORITMOCORRECTO//weights_l/weights.932-65.94.h5
# Epoch 933/2000
# 4216/4216 [==============================] - 12s 3ms/step - loss: 17.4841 - accuracy: 0.0000e+00 - val_loss: 64.0660 - val_accuracy: 0.0000e+00
#
# Epoch 00933: saving model to /gdrive/My Drive/ALGORITMOCORRECTO//weights_l/weights.933-64.07.h5
# Epoch 934/2000
# 4216/4216 [==============================] - 12s 3ms/step - loss: 17.4803 - accuracy: 0.0000e+00 - val_loss: 65.9383 - val_accuracy: 0.0000e+00
#
# Epoch 00934: saving model to /gdrive/My Drive/ALGORITMOCORRECTO//weights_l/weights.934-65.94.h5
# Epoch 935/2000
# 4216/4216 [==============================] - 12s 3ms/step - loss: 17.4595 - accuracy: 0.0000e+00 - val_loss: 64.0554 - val_accuracy: 0.0000e+00
#
# Epoch 00935: saving model to /gdrive/My Drive/ALGORITMOCORRECTO//weights_l/weights.935-64.06.h5
# Epoch 936/2000
# 4216/4216 [==============================] - 12s 3ms/step - loss: 17.4937 - accuracy: 0.0000e+00 - val_loss: 64.3146 - val_accuracy: 0.0000e+00
#
# Epoch 00936: saving model to /gdrive/My Drive/ALGORITMOCORRECTO//weights_l/weights.936-64.31.h5
# Epoch 937/2000
# 4216/4216 [==============================] - 12s 3ms/step - loss: 17.4494 - accuracy: 0.0000e+00 - val_loss: 64.1354 - val_accuracy: 0.0000e+00
#
# Epoch 00937: saving model to /gdrive/My Drive/ALGORITMOCORRECTO//weights_l/weights.937-64.14.h5
# Epoch 938/2000
# ...
# Epoch 1939/2000
# 4216/4216 [==============================] - 13s 3ms/step - loss: 17.2238 - accuracy: 0.0000e+00 - val_loss: 65.0330 - val_accuracy: 0.0000e+00
#
# Epoch 01939: saving model to /gdrive/My Drive/ALGORITMOCORRECTO//weights_l/weights.1939-65.03.h5
# Epoch 1940/2000
# 4216/4216 [==============================] - 13s 3ms/step - loss: 17.2385 - accuracy: 0.0000e+00 - val_loss: 67.3839 - val_accuracy: 0.0000e+00
#
# Epoch 01940: saving model to /gdrive/My Drive/ALGORITMOCORRECTO//weights_l/weights.1940-67.38.h5
# Epoch 1941/2000
# 4216/4216 [==============================] - 13s 3ms/step - loss: 17.2479 - accuracy: 0.0000e+00 - val_loss: 63.8505 - val_accuracy: 0.0000e+00
#
# Epoch 01941: saving model to /gdrive/My Drive/ALGORITMOCORRECTO//weights_l/weights.1941-63.85.h5
# Epoch 1942/2000
# 4216/4216 [==============================] - 13s 3ms/step - loss: 17.2400 - accuracy: 0.0000e+00 - val_loss: 66.1733 - val_accuracy: 0.0000e+00
#
# Epoch 01942: saving model to /gdrive/My Drive/ALGORITMOCORRECTO//weights_l/weights.1942-66.17.h5
# Epoch 1943/2000
# 4216/4216 [==============================] - 13s 3ms/step - loss: 17.2348 - accuracy: 0.0000e+00 - val_loss: 65.9606 - val_accuracy: 0.0000e+00
#
# Epoch 01943: saving model to /gdrive/My Drive/ALGORITMOCORRECTO//weights_l/weights.1943-65.96.h5
# Epoch 1944/2000
# 4216/4216 [==============================] - 13s 3ms/step - loss: 17.2359 - accuracy: 0.0000e+00 - val_loss: 65.7530 - val_accuracy: 0.0000e+00
#
# Epoch 01944: saving model to /gdrive/My Drive/ALGORITMOCORRECTO//weights_l/weights.1944-65.75.h5
# Epoch 1945/2000
# 4216/4216 [==============================] - 13s 3ms/step - loss: 17.2462 - accuracy: 0.0000e+00 - val_loss: 66.0939 - val_accuracy: 0.0000e+00
#
# Epoch 01945: saving model to /gdrive/My Drive/ALGORITMOCORRECTO//weights_l/weights.1945-66.09.h5
# Epoch 1946/2000
# 4216/4216 [==============================] - 13s 3ms/step - loss: 17.2316 - accuracy: 0.0000e+00 - val_loss: 65.8343 - val_accuracy: 0.0000e+00
#
# Epoch 01946: saving model to /gdrive/My Drive/ALGORITMOCORRECTO//weights_l/weights.1946-65.83.h5
# Epoch 1947/2000
# 4216/4216 [==============================] - 13s 3ms/step - loss: 17.2404 - accuracy: 0.0000e+00 - val_loss: 64.5571 - val_accuracy: 0.0000e+00
#
# Epoch 01947: saving model to /gdrive/My Drive/ALGORITMOCORRECTO//weights_l/weights.1947-64.56.h5
# Epoch 1948/2000
# 4216/4216 [==============================] - 13s 3ms/step - loss: 17.2404 - accuracy: 0.0000e+00 - val_loss: 66.4886 - val_accuracy: 0.0000e+00
#
# Epoch 01948: saving model to /gdrive/My Drive/ALGORITMOCORRECTO//weights_l/weights.1948-66.49.h5
# Epoch 1949/2000
# 4216/4216 [==============================] - 13s 3ms/step - loss: 17.2527 - accuracy: 0.0000e+00 - val_loss: 65.3833 - val_accuracy: 0.0000e+00
#
# Epoch 01949: saving model to /gdrive/My Drive/ALGORITMOCORRECTO//weights_l/weights.1949-65.38.h5
# Epoch 1950/2000
# 4216/4216 [==============================] - 13s 3ms/step - loss: 17.2351 - accuracy: 0.0000e+00 - val_loss: 66.2129 - val_accuracy: 0.0000e+00
#
# Epoch 01950: saving model to /gdrive/My Drive/ALGORITMOCORRECTO//weights_l/weights.1950-66.21.h5
# Epoch 1951/2000
# 4216/4216 [==============================] - 13s 3ms/step - loss: 17.2383 - accuracy: 0.0000e+00 - val_loss: 65.0867 - val_accuracy: 0.0000e+00
#
# Epoch 01951: saving model to /gdrive/My Drive/ALGORITMOCORRECTO//weights_l/weights.1951-65.09.h5
# Epoch 1952/2000
# 4216/4216 [==============================] - 13s 3ms/step - loss: 17.2556 - accuracy: 0.0000e+00 - val_loss: 66.8148 - val_accuracy: 0.0000e+00
#
# Epoch 01952: saving model to /gdrive/My Drive/ALGORITMOCORRECTO//weights_l/weights.1952-66.81.h5
# Epoch 1953/2000
# 4216/4216 [==============================] - 13s 3ms/step - loss: 17.2279 - accuracy: 0.0000e+00 - val_loss: 65.7825 - val_accuracy: 0.0000e+00
#
# Epoch 01953: saving model to /gdrive/My Drive/ALGORITMOCORRECTO//weights_l/weights.1953-65.78.h5
# Epoch 1954/2000
# 4216/4216 [==============================] - 13s 3ms/step - loss: 17.2346 - accuracy: 0.0000e+00 - val_loss: 65.7980 - val_accuracy: 0.0000e+00
#
# Epoch 01954: saving model to /gdrive/My Drive/ALGORITMOCORRECTO//weights_l/weights.1954-65.80.h5
# Epoch 1955/2000
# 4216/4216 [==============================] - 13s 3ms/step - loss: 17.2664 - accuracy: 0.0000e+00 - val_loss: 65.3714 - val_accuracy: 0.0000e+00
#
# Epoch 01955: saving model to /gdrive/My Drive/ALGORITMOCORRECTO//weights_l/weights.1955-65.37.h5
# Epoch 1956/2000
# 4216/4216 [==============================] - 13s 3ms/step - loss: 17.2444 - accuracy: 0.0000e+00 - val_loss: 65.7277 - val_accuracy: 0.0000e+00
#
# Epoch 01956: saving model to /gdrive/My Drive/ALGORITMOCORRECTO//weights_l/weights.1956-65.73.h5
# Epoch 1957/2000
# 4216/4216 [==============================] - 13s 3ms/step - loss: 17.2302 - accuracy: 0.0000e+00 - val_loss: 64.4913 - val_accuracy: 0.0000e+00
#
# Epoch 01957: saving model to /gdrive/My Drive/ALGORITMOCORRECTO//weights_l/weights.1957-64.49.h5
# Epoch 1958/2000
# 4216/4216 [==============================] - 13s 3ms/step - loss: 17.2292 - accuracy: 0.0000e+00 - val_loss: 65.4043 - val_accuracy: 0.0000e+00
#
# Epoch 01958: saving model to /gdrive/My Drive/ALGORITMOCORRECTO//weights_l/weights.1958-65.40.h5
# Epoch 1959/2000
# 4216/4216 [==============================] - 13s 3ms/step - loss: 17.2142 - accuracy: 0.0000e+00 - val_loss: 66.2527 - val_accuracy: 0.0000e+00
#
# Epoch 01959: saving model to /gdrive/My Drive/ALGORITMOCORRECTO//weights_l/weights.1959-66.25.h5
# Epoch 1960/2000
# 4216/4216 [==============================] - 13s 3ms/step - loss: 17.2613 - accuracy: 0.0000e+00 - val_loss: 65.1969 - val_accuracy: 0.0000e+00
#
# Epoch 01960: saving model to /gdrive/My Drive/ALGORITMOCORRECTO//weights_l/weights.1960-65.20.h5
# Epoch 1961/2000
# 4216/4216 [==============================] - 13s 3ms/step - loss: 17.2369 - accuracy: 0.0000e+00 - val_loss: 65.6109 - val_accuracy: 0.0000e+00
#
# Epoch 01961: saving model to /gdrive/My Drive/ALGORITMOCORRECTO//weights_l/weights.1961-65.61.h5
# Epoch 1962/2000
# 4216/4216 [==============================] - 13s 3ms/step - loss: 17.2406 - accuracy: 0.0000e+00 - val_loss: 66.6664 - val_accuracy: 0.0000e+00
#
# Epoch 01962: saving model to /gdrive/My Drive/ALGORITMOCORRECTO//weights_l/weights.1962-66.67.h5
# Epoch 1963/2000
# 4216/4216 [==============================] - 13s 3ms/step - loss: 17.2549 - accuracy: 0.0000e+00 - val_loss: 66.6633 - val_accuracy: 0.0000e+00
#
# Epoch 01963: saving model to /gdrive/My Drive/ALGORITMOCORRECTO//weights_l/weights.1963-66.66.h5
# Epoch 1964/2000
# 4216/4216 [==============================] - 13s 3ms/step - loss: 17.2456 - accuracy: 0.0000e+00 - val_loss: 65.2471 - val_accuracy: 0.0000e+00
#
# Epoch 01964: saving model to /gdrive/My Drive/ALGORITMOCORRECTO//weights_l/weights.1964-65.25.h5
# Epoch 1965/2000
# 4216/4216 [==============================] - 13s 3ms/step - loss: 17.2066 - accuracy: 0.0000e+00 - val_loss: 65.5592 - val_accuracy: 0.0000e+00
#
# Epoch 01965: saving model to /gdrive/My Drive/ALGORITMOCORRECTO//weights_l/weights.1965-65.56.h5
# Epoch 1966/2000
# 4216/4216 [==============================] - 13s 3ms/step - loss: 17.2353 - accuracy: 0.0000e+00 - val_loss: 66.2123 - val_accuracy: 0.0000e+00
#
# Epoch 01966: saving model to /gdrive/My Drive/ALGORITMOCORRECTO//weights_l/weights.1966-66.21.h5
# Epoch 1967/2000
# 4216/4216 [==============================] - 13s 3ms/step - loss: 17.2489 - accuracy: 0.0000e+00 - val_loss: 65.9415 - val_accuracy: 0.0000e+00
#
# Epoch 01967: saving model to /gdrive/My Drive/ALGORITMOCORRECTO//weights_l/weights.1967-65.94.h5
# Epoch 1968/2000
# 4216/4216 [==============================] - 13s 3ms/step - loss: 17.2396 - accuracy: 0.0000e+00 - val_loss: 65.4655 - val_accuracy: 0.0000e+00
#
# Epoch 01968: saving model to /gdrive/My Drive/ALGORITMOCORRECTO//weights_l/weights.1968-65.47.h5
# Epoch 1969/2000
# 4216/4216 [==============================] - 13s 3ms/step - loss: 17.2459 - accuracy: 0.0000e+00 - val_loss: 64.6900 - val_accuracy: 0.0000e+00
#
# Epoch 01969: saving model to /gdrive/My Drive/ALGORITMOCORRECTO//weights_l/weights.1969-64.69.h5
# Epoch 1970/2000
# 4216/4216 [==============================] - 13s 3ms/step - loss: 17.2247 - accuracy: 0.0000e+00 - val_loss: 64.3989 - val_accuracy: 0.0000e+00
#
# Epoch 01970: saving model to /gdrive/My Drive/ALGORITMOCORRECTO//weights_l/weights.1970-64.40.h5
# Epoch 1971/2000
# 4216/4216 [==============================] - 13s 3ms/step - loss: 17.2584 - accuracy: 0.0000e+00 - val_loss: 65.2248 - val_accuracy: 0.0000e+00
#
# Epoch 01971: saving model to /gdrive/My Drive/ALGORITMOCORRECTO//weights_l/weights.1971-65.22.h5
# Epoch 1972/2000
# 4216/4216 [==============================] - 13s 3ms/step - loss: 17.2389 - accuracy: 0.0000e+00 - val_loss: 64.7772 - val_accuracy: 0.0000e+00
#
# Epoch 01972: saving model to /gdrive/My Drive/ALGORITMOCORRECTO//weights_l/weights.1972-64.78.h5
# Epoch 1973/2000
# 4216/4216 [==============================] - 14s 3ms/step - loss: 17.2191 - accuracy: 0.0000e+00 - val_loss: 65.0187 - val_accuracy: 0.0000e+00
#
# Epoch 01973: saving model to /gdrive/My Drive/ALGORITMOCORRECTO//weights_l/weights.1973-65.02.h5
# Epoch 1974/2000
# 4216/4216 [==============================] - 13s 3ms/step - loss: 17.2773 - accuracy: 0.0000e+00 - val_loss: 66.3853 - val_accuracy: 0.0000e+00
#
# Epoch 01974: saving model to /gdrive/My Drive/ALGORITMOCORRECTO//weights_l/weights.1974-66.39.h5
# Epoch 1975/2000
# 4216/4216 [==============================] - 13s 3ms/step - loss: 17.2439 - accuracy: 0.0000e+00 - val_loss: 64.6386 - val_accuracy: 0.0000e+00
#
# Epoch 01975: saving model to /gdrive/My Drive/ALGORITMOCORRECTO//weights_l/weights.1975-64.64.h5
# Epoch 1976/2000
# 4216/4216 [==============================] - 13s 3ms/step - loss: 17.2596 - accuracy: 0.0000e+00 - val_loss: 67.4836 - val_accuracy: 0.0000e+00
#
# Epoch 01976: saving model to /gdrive/My Drive/ALGORITMOCORRECTO//weights_l/weights.1976-67.48.h5
# Epoch 1977/2000
# 4216/4216 [==============================] - 13s 3ms/step - loss: 17.2239 - accuracy: 0.0000e+00 - val_loss: 66.2016 - val_accuracy: 0.0000e+00
#
# Epoch 01977: saving model to /gdrive/My Drive/ALGORITMOCORRECTO//weights_l/weights.1977-66.20.h5
# Epoch 1978/2000
# 4216/4216 [==============================] - 13s 3ms/step - loss: 17.2543 - accuracy: 0.0000e+00 - val_loss: 64.9404 - val_accuracy: 0.0000e+00
#
# Epoch 01978: saving model to /gdrive/My Drive/ALGORITMOCORRECTO//weights_l/weights.1978-64.94.h5
# Epoch 1979/2000
# 4216/4216 [==============================] - 13s 3ms/step - loss: 17.2456 - accuracy: 0.0000e+00 - val_loss: 64.3219 - val_accuracy: 0.0000e+00
#
# Epoch 01979: saving model to /gdrive/My Drive/ALGORITMOCORRECTO//weights_l/weights.1979-64.32.h5
# Epoch 1980/2000
# 4216/4216 [==============================] - 14s 3ms/step - loss: 17.2462 - accuracy: 0.0000e+00 - val_loss: 65.0771 - val_accuracy: 0.0000e+00
#
# Epoch 01980: saving model to /gdrive/My Drive/ALGORITMOCORRECTO//weights_l/weights.1980-65.08.h5
# Epoch 1981/2000
# 4216/4216 [==============================] - 14s 3ms/step - loss: 17.2312 - accuracy: 0.0000e+00 - val_loss: 66.1627 - val_accuracy: 0.0000e+00
#
# Epoch 01981: saving model to /gdrive/My Drive/ALGORITMOCORRECTO//weights_l/weights.1981-66.16.h5
# Epoch 1982/2000
# 4216/4216 [==============================] - 14s 3ms/step - loss: 17.2110 - accuracy: 0.0000e+00 - val_loss: 64.6873 - val_accuracy: 0.0000e+00
#
# Epoch 01982: saving model to /gdrive/My Drive/ALGORITMOCORRECTO//weights_l/weights.1982-64.69.h5
# Epoch 1983/2000
# 4216/4216 [==============================] - 14s 3ms/step - loss: 17.2330 - accuracy: 0.0000e+00 - val_loss: 65.4177 - val_accuracy: 0.0000e+00
#
# Epoch 01983: saving model to /gdrive/My Drive/ALGORITMOCORRECTO//weights_l/weights.1983-65.42.h5
# Epoch 1984/2000
# 4216/4216 [==============================] - 13s 3ms/step - loss: 17.2283 - accuracy: 0.0000e+00 - val_loss: 65.2921 - val_accuracy: 0.0000e+00
#
# Epoch 01984: saving model to /gdrive/My Drive/ALGORITMOCORRECTO//weights_l/weights.1984-65.29.h5
# Epoch 1985/2000
# 4216/4216 [==============================] - 13s 3ms/step - loss: 17.2473 - accuracy: 0.0000e+00 - val_loss: 66.3324 - val_accuracy: 0.0000e+00
#
# Epoch 01985: saving model to /gdrive/My Drive/ALGORITMOCORRECTO//weights_l/weights.1985-66.33.h5
# Epoch 1986/2000
# 4216/4216 [==============================] - 13s 3ms/step - loss: 17.2499 - accuracy: 0.0000e+00 - val_loss: 64.8488 - val_accuracy: 0.0000e+00
#
# Epoch 01986: saving model to /gdrive/My Drive/ALGORITMOCORRECTO//weights_l/weights.1986-64.85.h5
# Epoch 1987/2000
# 4216/4216 [==============================] - 13s 3ms/step - loss: 17.2427 - accuracy: 0.0000e+00 - val_loss: 65.1029 - val_accuracy: 0.0000e+00
#
# Epoch 01987: saving model to /gdrive/My Drive/ALGORITMOCORRECTO//weights_l/weights.1987-65.10.h5
# Epoch 1988/2000
# 4216/4216 [==============================] - 13s 3ms/step - loss: 17.2040 - accuracy: 0.0000e+00 - val_loss: 65.4908 - val_accuracy: 0.0000e+00
#
# Epoch 01988: saving model to /gdrive/My Drive/ALGORITMOCORRECTO//weights_l/weights.1988-65.49.h5
# Epoch 1989/2000
# 4216/4216 [==============================] - 13s 3ms/step - loss: 17.2229 - accuracy: 0.0000e+00 - val_loss: 64.5688 - val_accuracy: 0.0000e+00
#
# Epoch 01989: saving model to /gdrive/My Drive/ALGORITMOCORRECTO//weights_l/weights.1989-64.57.h5
# Epoch 1990/2000
# 4216/4216 [==============================] - 13s 3ms/step - loss: 17.2101 - accuracy: 0.0000e+00 - val_loss: 64.5939 - val_accuracy: 0.0000e+00
#
# Epoch 01990: saving model to /gdrive/My Drive/ALGORITMOCORRECTO//weights_l/weights.1990-64.59.h5
# Epoch 1991/2000
# 4216/4216 [==============================] - 13s 3ms/step - loss: 17.2226 - accuracy: 0.0000e+00 - val_loss: 65.4904 - val_accuracy: 0.0000e+00
#
# Epoch 01991: saving model to /gdrive/My Drive/ALGORITMOCORRECTO//weights_l/weights.1991-65.49.h5
# Epoch 1992/2000
# 4216/4216 [==============================] - 13s 3ms/step - loss: 17.2431 - accuracy: 0.0000e+00 - val_loss: 64.1508 - val_accuracy: 0.0000e+00
#
# Epoch 01992: saving model to /gdrive/My Drive/ALGORITMOCORRECTO//weights_l/weights.1992-64.15.h5
# Epoch 1993/2000
# 4216/4216 [==============================] - 13s 3ms/step - loss: 17.2516 - accuracy: 0.0000e+00 - val_loss: 66.1836 - val_accuracy: 0.0000e+00
#
# Epoch 01993: saving model to /gdrive/My Drive/ALGORITMOCORRECTO//weights_l/weights.1993-66.18.h5
# Epoch 1994/2000
# 4216/4216 [==============================] - 13s 3ms/step - loss: 17.2370 - accuracy: 0.0000e+00 - val_loss: 65.0833 - val_accuracy: 0.0000e+00
#
# Epoch 01994: saving model to /gdrive/My Drive/ALGORITMOCORRECTO//weights_l/weights.1994-65.08.h5
# Epoch 1995/2000
# 4216/4216 [==============================] - 13s 3ms/step - loss: 17.2330 - accuracy: 0.0000e+00 - val_loss: 65.0931 - val_accuracy: 0.0000e+00
#
# Epoch 01995: saving model to /gdrive/My Drive/ALGORITMOCORRECTO//weights_l/weights.1995-65.09.h5
# Epoch 1996/2000
# 4216/4216 [==============================] - 13s 3ms/step - loss: 17.2355 - accuracy: 0.0000e+00 - val_loss: 66.5792 - val_accuracy: 0.0000e+00
#
# Epoch 01996: saving model to /gdrive/My Drive/ALGORITMOCORRECTO//weights_l/weights.1996-66.58.h5
# Epoch 1997/2000
# 4216/4216 [==============================] - 13s 3ms/step - loss: 17.2400 - accuracy: 0.0000e+00 - val_loss: 64.2879 - val_accuracy: 0.0000e+00
#
# Epoch 01997: saving model to /gdrive/My Drive/ALGORITMOCORRECTO//weights_l/weights.1997-64.29.h5
# Epoch 1998/2000
# 4216/4216 [==============================] - 13s 3ms/step - loss: 17.2804 - accuracy: 0.0000e+00 - val_loss: 66.3080 - val_accuracy: 0.0000e+00
#
# Epoch 01998: saving model to /gdrive/My Drive/ALGORITMOCORRECTO//weights_l/weights.1998-66.31.h5
# Epoch 1999/2000
# 4216/4216 [==============================] - 13s 3ms/step - loss: 17.2394 - accuracy: 0.0000e+00 - val_loss: 64.7735 - val_accuracy: 0.0000e+00
#
# Epoch 01999: saving model to /gdrive/My Drive/ALGORITMOCORRECTO//weights_l/weights.1999-64.77.h5
# Epoch 2000/2000
# 4216/4216 [==============================] - 13s 3ms/step - loss: 17.2386 - accuracy: 0.0000e+00 - val_loss: 66.6334 - val_accuracy: 0.0000e+00
#
# Epoch 02000: saving model to /gdrive/My Drive/ALGORITMOCORRECTO//weights_l/weights.2000-66.63.h5

# %%
# %tensorboard --logdir logs
