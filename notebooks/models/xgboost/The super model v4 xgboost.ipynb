# %%
import pandas as pd
import numpy as np

# %%
from google.colab import drive
drive.mount('/gdrive')
PATH='/gdrive/My Drive/ALGORITMOCORRECTO/'
# Out:
# Drive already mounted at /gdrive; to attempt to forcibly remount, call drive.mount("/gdrive", force_remount=True).

# %%
df=pd.read_csv(f'{PATH}/frankenstainV2.csv')
# Out:
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:2718: DtypeWarning: Columns (42) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
df.head()
# Out:
#    Unnamed: 0  field_1       id  ...  RESPONSABL  SHAPE_Leng   SHAPE_Area
# 0           0        3  1125506  ...         560   455.44384 11,733.28557
# 1           1        4  1204569  ...         560   526.72535 13,106.71596
# 2           2        8   958538  ...         560   907.39527 43,417.20083
# 3           3       12  1084087  ...         560   117.39756    832.53782
# 4           4       13  1204653  ...         560   227.99827  2,922.62256
#
# [5 rows x 52 columns]

# %%
pd.options.display.float_format = '{:,.5f}'.format

# %%
df
# Out:
#         Unnamed: 0  field_1       id  ...  RESPONSABL  SHAPE_Leng   SHAPE_Area
# 0                0        3  1125506  ...         560   455.44384 11,733.28557
# 1                1        4  1204569  ...         560   526.72535 13,106.71596
# 2                2        8   958538  ...         560   907.39527 43,417.20083
# 3                3       12  1084087  ...         560   117.39756    832.53782
# 4                4       13  1204653  ...         560   227.99827  2,922.62256
# ...            ...      ...      ...  ...         ...         ...          ...
# 136235      136235   244425  1403961  ...         560   510.65670 14,347.74848
# 136236      136236   244430  1393020  ...         560   240.00359  2,699.82037
# 136237      136237   244431   490880  ...         560   538.26785 16,035.20752
# 136238      136238   244432  1383758  ...         560   755.33828 28,571.90781
# 136239      136239   244433  1381410  ...         560   941.93076 22,603.30703
#
# [136240 rows x 52 columns]

# %% [markdown]
# ## Delete dummy variables

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'field_1', 'id', 'area', 'ascensor', 'balcon', 'banos',
#        'banoservicio', 'conjuntocerrado', 'cuartoservicio', 'deposito',
#        'estrato', 'estudio', 'garajes', 'gimnasio', 'habitaciones',
#        'halldealcobas', 'parqueaderovisitantes', 'piscina', 'piso', 'porteria',
#        'remodelado', 'saloncomunal', 'terraza', 'tiempodeconstruido',
#        'vigilancia', 'vista', 'zonalavanderia', 'valoradministracion',
#        'valorventa', 'tipoinmueble', 'tiponegocio', 'latitud', 'longitud',
#        'val_mcuadrado', '0-1 anos', '1-10 anos', '10-30 anos', '30 anos',
#        'CODIGO_MAN', 'ESTRATO_2', 'CODIGO_ZON', 'CODIGO_CRI', 'NORMATIVA',
#        'ACTO_ADMIN', 'NUMERO_ACT', 'FECHA_ACTO', 'ESCALA_CAP', 'FECHA_CAPT',
#        'RESPONSABL', 'SHAPE_Leng', 'SHAPE_Area'],
#       dtype='object')

# %%
columns_to_delete=[
                   'conjuntocerrado',
                   'Unnamed: 0',
                   'field_1',
                    'id',
                    'ascensor',
                    'balcon',
                    'cuartoservicio',
                    'deposito',
                    'estudio',
                    'gimnasio',
                    'halldealcobas',
                    'parqueaderovisitantes',
                    'piscina',
                    'porteria' ,
                    'remodelado',
                    'saloncomunal',
                    'terraza',
                    'vigilancia',
                    'vista',
                    'zonalavanderia',
                    'CODIGO_MAN',
                    'ESTRATO_2',
                    'CODIGO_ZON',
                    'CODIGO_CRI',
                    'NORMATIVA',
                    'ACTO_ADMIN',
                    'NUMERO_ACT',
                    'FECHA_ACTO',
                    'ESCALA_CAP',
                    'FECHA_CAPT',
                    'RESPONSABL',
                    'SHAPE_Leng',
                    'SHAPE_Area',
                   'tiempodeconstruido',
                   'banoservicio',
                   ]

# %%
# %%time
# df['piso'] = df['piso'].replace(np.nan, 1)

# %%
# %%time
df['piso'] = df['piso'].fillna(1)

# %%
df['garajes'] = df['garajes'].fillna(method='ffill')

# %%
df.describe()
# Out:
#          Unnamed: 0       field_1  ...    SHAPE_Leng      SHAPE_Area
# count 136,240.00000 136,240.00000  ... 136,240.00000   136,240.00000
# mean   68,119.50000 125,152.08219  ...     765.96687    48,963.53198
# std    39,329.24467  70,534.46113  ...     848.39833   176,017.90625
# min         0.00000       3.00000  ...      50.38536       120.78306
# 25%    34,059.75000  63,352.50000  ...     367.29184     6,885.42907
# 50%    68,119.50000 128,341.50000  ...     529.42877    12,906.35311
# 75%   102,179.25000 185,680.50000  ...     833.61709    30,788.83975
# max   136,239.00000 244,433.00000  ...  15,822.56292 6,786,206.48621
#
# [8 rows x 42 columns]

# %%
import seaborn as sb

# %%
df=df[(df.banos>0) & (df.banos<20)]

# %%
def delete_garbage_columns(df):
  for i in columns_to_delete:
    try:
      df.pop(i)
    except Exception as e:
      print(e)
  return df

# %%
df = delete_garbage_columns(df)

# %%
df.head()
# Out:
#          area   banos  estrato  ...  1-10 anos  10-30 anos  30 anos
# 982  51.00000 2.00000        2  ...          0           0        0
# 983 172.00000 2.00000        3  ...          0           0        0
# 984 144.00000 2.00000        2  ...          0           0        0
# 985 132.25000 2.00000        2  ...          0           0        0
# 986 134.00000 2.00000        1  ...          0           0        0
#
# [5 rows x 17 columns]

# %% [markdown]
# ## Add onehot encoding to category variables

# %%
def AddOnehotEncoding(df):
  
  try:
    one_hot_magic={
      '0-1 anos': ['Menos de 1 año'],
      '1-10 anos': ['ntre 0 y 5 años', 'Entre 0 y 5 años', '1 a 8 años', 'Entre 5 y 10 años'],
      '10-30 anos': ['9 a 15 años', 'Entre 10 y 20 años', '16 a 30 años', 'Más de 20 años'],
      '30 anos': ['Más de 30 años'],
    }
    d = []
    for k, v in one_hot_magic.items():
      a = pd.Series([])
      for y in v:
        if len(df.value_counts()) <= 0:
          a=df.tiempodeconstruido == y
        else:
          a= a | df.tiempodeconstruido == y
      df[k] = a
      df[k]=df[k].replace(True, 1).replace(False, 0).astype(int)
  except Exception as e:
    print(e) 
  tiponegocio = pd.get_dummies(df.tiponegocio, prefix='tiponegocio')
  columns = tiponegocio.columns

  df['tiponegocio_Arriendo'] = tiponegocio['tiponegocio_Arriendo'] if 'tiponegocio_Arriendo' in columns else 0
  df['tiponegocio_Venta'] = tiponegocio['tiponegocio_Venta'] if 'tiponegocio_Venta' in columns else 0
  df['tiponegocio_Venta Y Arriendo'] = tiponegocio['tiponegocio_Venta Y Arriendo']+tiponegocio['tiponegocio_Venta y arriendo']	if 'tiponegocio_Venta Y Arriendo' in columns and 'tiponegocio_Venta y arriendo' in columns else 0
  df.pop('tiponegocio')

  tipoinmueble  = pd.get_dummies(df.tipoinmueble , prefix='tipoinmueble')

  df.pop('tipoinmueble')
  columns = tipoinmueble.columns
  df['tipoinmueble_Casa'] = tipoinmueble['tipoinmueble_Casa'] if 'tipoinmueble_Casa' in columns else 0
  df['tipoinmueble_Apartamento'] = tipoinmueble['tipoinmueble_Apartamento'] if 'tipoinmueble_Apartamento' in columns else 0   
  return df

# %%
df = AddOnehotEncoding(df)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:12: DeprecationWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   if sys.path[0] == '':
# 'DataFrame' object has no attribute 'tiempodeconstruido'
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:34: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:35: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %% [markdown]
# #Eliminar las variables a buscar

# %%
val_m=df.pop('val_mcuadrado')
df.pop('valorventa')
# Out:
# 982       130070000
# 983       470000000
# 984       108000000
# 985       149900000
# 986       140000000
#             ...
# 136224    120000000
# 136225    135000000
# 136226    167000000
# 136227    158000000
# 136228    138000000
# Name: valorventa, Length: 134910, dtype: int64

# %%
val_m.head()
# Out:
# 982   2,550,392.15686
# 983   2,732,558.13953
# 984     750,000.00000
# 985   1,133,459.35728
# 986   1,044,776.11940
# Name: val_mcuadrado, dtype: float64

# %%
import datetime
import pytz
colombia_time = pytz.timezone('America/Bogota')
def get_date():
  date = datetime.datetime.now(colombia_time)
  return date.strftime('%Y-%B-%d-%H:%M:%S')

# %%
df.to_csv(f'{PATH}/desconfianza_{get_date()}.csv')

# %%
df.head()
# Out:
#          area   banos  ...  tipoinmueble_Casa  tipoinmueble_Apartamento
# 982  51.00000 2.00000  ...                  0                         1
# 983 172.00000 2.00000  ...                  1                         0
# 984 144.00000 2.00000  ...                  1                         0
# 985 132.25000 2.00000  ...                  1                         0
# 986 134.00000 2.00000  ...                  1                         0
#
# [5 rows x 18 columns]

# %% [markdown]
# ## Load validation data

# %%
test_data=pd.read_csv(f'{PATH}/test_data.csv')

# %%
test_data = AddOnehotEncoding(test_data)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:12: DeprecationWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   if sys.path[0] == '':

# %%
test_data = delete_garbage_columns(test_data)
# Out:
# 'Unnamed: 0'
# 'field_1'
# 'CODIGO_MAN'
# 'ESTRATO_2'
# 'CODIGO_ZON'
# 'CODIGO_CRI'
# 'NORMATIVA'
# 'ACTO_ADMIN'
# 'NUMERO_ACT'
# 'FECHA_ACTO'
# 'ESCALA_CAP'
# 'FECHA_CAPT'
# 'RESPONSABL'
# 'SHAPE_Leng'
# 'SHAPE_Area'

# %%
val_m_test = test_data.valorventa/test_data.area
test_data.pop('valorventa')
# Out:
# 0    185,000,000.00000
# 1    498,000,000.00000
# 2    498,000,000.00000
# 3    519,000,000.00000
# 4    517,000,000.00000
# 5    514,990,000.00000
# 6    510,000,000.00000
# 7    520,000,000.00000
# 8    215,000,000.00000
# 9    519,000,000.00000
# 10   517,000,000.00000
# 11   519,000,000.00000
# 12   513,990,000.00000
# 13   514,660,000.00000
# 14   513,330,000.00000
# 15   514,330,000.00000
# 16   570,000,000.00000
# 17   310,000,000.00000
# 18   330,000,000.00000
# 19   330,000,000.00000
# 20   350,000,000.00000
# 21   320,000,000.00000
# 22   350,000,000.00000
# 23   330,000,000.00000
# 24   350,000,000.00000
# 25   315,000,000.00000
# 26   330,000,000.00000
# 27   330,000,000.00000
# 28   310,000,000.00000
# 29   350,000,000.00000
# 30   300,000,000.00000
# 31   330,000,000.00000
# 32   290,000,000.00000
# 33   290,000,000.00000
# 34   300,000,000.00000
# 35   310,000,000.00000
# 36   370,000,000.00000
# 37   390,000,000.00000
# 38   390,000,000.00000
# 39   370,000,000.00000
# 40   370,000,000.00000
# 41   360,000,000.00000
# 42   370,000,000.00000
# 43   370,000,000.00000
# 44   370,000,000.00000
# 45   370,000,000.00000
# 46   370,000,000.00000
# 47   799,000,000.00000
# 48   799,000,000.00000
# 49   749,000,000.00000
# 50   749,000,000.00000
# 51   699,000,000.00000
# 52   930,000,000.00000
# Name: valorventa, dtype: float64

# %%
val_m_test.head()
# Out:
# 0   1,778,846.15385
# 1   3,458,333.33333
# 2   3,458,333.33333
# 3   3,579,310.34483
# 4   3,565,517.24138
# dtype: float64

# %%
test_data.head()
# Out:
#        area   banos  ...  tipoinmueble_Casa  tipoinmueble_Apartamento
# 0 104.00000 2.00000  ...                  1                         0
# 1 144.00000 2.00000  ...                  1                         0
# 2 144.00000 2.00000  ...                  1                         0
# 3 145.00000 2.00000  ...                  1                         0
# 4 145.00000 2.00000  ...                  1                         0
#
# [5 rows x 18 columns]

# %%
len(test_data.columns)
# Out:
# 18

# %% [markdown]
# ## Model

# %%
# !pip install scikit-learn --upgrade
# Out:
# Requirement already up-to-date: scikit-learn in /usr/local/lib/python3.7/dist-packages (0.24.1)
# Requirement already satisfied, skipping upgrade: numpy>=1.13.3 in /usr/local/lib/python3.7/dist-packages (from scikit-learn) (1.19.5)
# Requirement already satisfied, skipping upgrade: threadpoolctl>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn) (2.1.0)
# Requirement already satisfied, skipping upgrade: joblib>=0.11 in /usr/local/lib/python3.7/dist-packages (from scikit-learn) (1.0.1)
# Requirement already satisfied, skipping upgrade: scipy>=0.19.1 in /usr/local/lib/python3.7/dist-packages (from scikit-learn) (1.4.1)

# %%
from sklearn.model_selection import GridSearchCV, RandomizedSearchCV
from sklearn.metrics import mean_absolute_percentage_error as MAPE
from xgboost import XGBRegressor

# %%
xgb1 = XGBRegressor()
parameters = {'nthread':[4],
              'objective':['reg:linear', 'reg:tweedie', 'reg:squarederror'],
              'learning_rate': [.03, 0.05, .07, .001],
              'max_depth': [5, 8, 10 , 20, 50],
              'min _child_weight': [2, 4],
              'silent': [1],
              'subsample': [0.7],
              'colsample_bytree': [0.7],
              'n_estimators': [50,100,250]}

xgb_grid = RandomizedSearchCV(xgb1,
                        parameters,
                        n_jobs = -1,
                        verbose=True)

xgb_grid.fit(df,val_m)
# Out:
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# RandomizedSearchCV(estimator=XGBRegressor(), n_jobs=-1,
#                    param_distributions={'colsample_bytree': [0.7],
#                                         'learning_rate': [0.03, 0.05, 0.07,
#                                                           0.001],
#                                         'max_depth': [5, 8, 10, 20, 50],
#                                         'min_child_weight': [2, 4],
#                                         'n_estimators': [50, 100, 250],
#                                         'nthread': [4],
#                                         'objective': ['reg:linear',
#                                                       'reg:tweedie',
#                                                       'reg:squarederror'],
#                                         'silent': [1], 'subsample': [0.7]},
#                    verbose=True)

# %%
print(xgb_grid.best_score_)
print(xgb_grid.best_params_)
# Out:
# 0.7921229377742549
# {'subsample': 0.7, 'silent': 1, 'objective': 'reg:squarederror', 'nthread': 4, 'n_estimators': 100, 'min_child_weight': 4, 'max_depth': 50, 'learning_rate': 0.07, 'colsample_bytree': 0.7}

# %%
y_pred = xgb_grid.predict(test_data)
MAPE(val_m_test, y_pred)
# Out:
# 0.084053421829279

# %%
import joblib
joblib.dump(xgb_grid.best_estimator_, f'{PATH}/xgboost_estimator.pkl')
# Out:
# ['/gdrive/My Drive/ALGORITMOCORRECTO//xgboost_estimator.pkl']

# %%
test_data=pd.read_csv(f'{PATH}/test_data.csv')

# %%
test_data.head()
# Out:
#         id      area  ascensor  ...  tiponegocio  latitud  longitud
# 0   877392 104.00000       nan  ...        Venta  4.71150 -74.13238
# 1   201483 144.00000       nan  ...        Venta  4.70064 -74.09008
# 2   188674 144.00000       nan  ...        Venta  4.70058 -74.09008
# 3  1211067 145.00000       nan  ...        Venta  4.70252 -74.09137
# 4   883437 145.00000       nan  ...        Venta  4.70141 -74.09325
#
# [5 rows x 32 columns]

# %%
test_data
# Out:
#          id      area  ascensor  ...  tiponegocio  latitud  longitud
# 0    877392 104.00000       nan  ...        Venta  4.71150 -74.13238
# 1    201483 144.00000       nan  ...        Venta  4.70064 -74.09008
# 2    188674 144.00000       nan  ...        Venta  4.70058 -74.09008
# 3   1211067 145.00000       nan  ...        Venta  4.70252 -74.09137
# 4    883437 145.00000       nan  ...        Venta  4.70141 -74.09325
# 5    332550 145.00000       nan  ...        Venta  4.70184 -74.09206
# 6    320585 145.00000       nan  ...        Venta  4.69932 -74.09261
# 7    776969 145.00000       nan  ...        Venta  4.70201 -74.09240
# 8    435344 105.00000       nan  ...        Venta  4.71048 -74.13275
# 9   1274573 146.00000       nan  ...        Venta  4.69927 -74.09085
# 10   846305 146.00000       nan  ...        Venta  4.70056 -74.09283
# 11  1345443 146.00000       nan  ...        Venta  4.70101 -74.09090
# 12   550169 147.00000       nan  ...        Venta  4.70098 -74.09103
# 13   502072 147.00000       nan  ...        Venta  4.70098 -74.09154
# 14   514698 147.00000       nan  ...        Venta  4.70116 -74.09188
# 15   424985 147.00000       nan  ...        Venta  4.69987 -74.09128
# 16  1026142 150.00000       nan  ...        Venta  4.70075 -74.09039
# 17   736991 144.00000       nan  ...        Venta  4.74397 -74.06391
# 18   394757 144.00000       nan  ...        Venta  4.74465 -74.06297
# 19   398647 144.00000       nan  ...        Venta  4.74430 -74.06348
# 20   253068 144.00000       nan  ...        Venta  4.74481 -74.06382
# 21   511414 144.00000       nan  ...        Venta  4.74424 -74.06367
# 22   231053 144.00000       nan  ...        Venta  4.74399 -74.06403
# 23   526879 144.00000       nan  ...        Venta  4.74433 -74.06311
# 24   798974 144.00000       nan  ...        Venta  4.74456 -74.06300
# 25   830409 144.00000       nan  ...        Venta  4.74414 -74.06315
# 26   431272 144.00000       nan  ...        Venta  4.74425 -74.06352
# 27   630631 144.00000       nan  ...        Venta  4.74422 -74.06363
# 28   763398 144.00000       nan  ...        Venta  4.74438 -74.06348
# 29   276759 138.00000       nan  ...        Venta  4.74402 -74.06395
# 30  1368608 140.00000       nan  ...        Venta  4.74451 -74.06306
# 31   317703 140.00000       nan  ...        Venta  4.74398 -74.06325
# 32  1221098 140.00000       nan  ...        Venta  4.74384 -74.06329
# 33  1257103 140.00000       nan  ...        Venta  4.74448 -74.06308
# 34  1323936 140.00000       nan  ...        Venta  4.74424 -74.06339
# 35  1303633 140.00000       nan  ...        Venta  4.74471 -74.06429
# 36   946955 150.00000       nan  ...        Venta  4.63340 -74.14656
# 37   425047 150.00000       nan  ...        Venta  4.63409 -74.14570
# 38   783014 150.00000       nan  ...        Venta  4.63409 -74.14613
# 39   495811 150.00000       nan  ...        Venta  4.63460 -74.14552
# 40  1011258 150.00000       nan  ...        Venta  4.63400 -74.14639
# 41    78622 150.00000       nan  ...        Venta  4.63375 -74.14656
# 42   326168 150.00000       nan  ...        Venta  4.63383 -74.14656
# 43   544485 150.00000       nan  ...        Venta  4.63486 -74.14578
# 44   939843 150.00000       nan  ...        Venta  4.63409 -74.14647
# 45   825791 150.00000       nan  ...        Venta  4.63366 -74.14690
# 46   543441 150.00000       nan  ...        Venta  4.63434 -74.14621
# 47   486184 230.00000       nan  ...        Venta  4.73599 -74.03835
# 48   726088 230.00000       nan  ...        Venta  4.73703 -74.03829
# 49   752156 230.00000       nan  ...        Venta  4.73584 -74.03844
# 50  1055205 230.00000       nan  ...        Venta  4.73606 -74.04063
# 51  1289402 230.00000       nan  ...        Venta  4.73762 -74.04019
# 52   372796 230.00000       nan  ...        Venta  4.70265 -74.05847
#
# [53 rows x 32 columns]

# %%
data_res={
    'id': test_data.id,
    'valormt2_predicted':y_pred,
 }

# %%
data_res
# Out:
# {'id': 0      877392
#  1      201483
#  2      188674
#  3     1211067
#  4      883437
#  5      332550
#  6      320585
#  7      776969
#  8      435344
#  9     1274573
#  10     846305
#  11    1345443
#  12     550169
#  13     502072
#  14     514698
#  15     424985
#  16    1026142
#  17     736991
#  18     394757
#  19     398647
#  20     253068
#  21     511414
#  22     231053
#  23     526879
#  24     798974
#  25     830409
#  26     431272
#  27     630631
#  28     763398
#  29     276759
#  30    1368608
#  31     317703
#  32    1221098
#  33    1257103
#  34    1323936
#  35    1303633
#  36     946955
#  37     425047
#  38     783014
#  39     495811
#  40    1011258
#  41      78622
#  42     326168
#  43     544485
#  44     939843
#  45     825791
#  46     543441
#  47     486184
#  48     726088
#  49     752156
#  50    1055205
#  51    1289402
#  52     372796
#  Name: id, dtype: int64,
#  'valormt2_predicted': array([1875704. , 2482750.5, 2482750.5, 3070635.8, 3214901. , 3061350.2,
#         3349587. , 3321994. , 1939503.6, 2777642.8, 3146173.2, 2599270.5,
#         3069680.5, 3155607.8, 3083971. , 2890692. , 2722635.8, 2530603.2,
#         2174029. , 2261380.2, 2300199.5, 2497094. , 2637754.8, 2259034.8,
#         2103490.5, 2340417.8, 2347861. , 2440461.2, 2271788.8, 2824074. ,
#         2115463. , 2178009.2, 2221529. , 2075092.4, 2216227.2, 2163032.8,
#         2526958. , 2605939. , 2565593. , 2816631.5, 2479138.2, 2493650. ,
#         2493650. , 2604675.2, 2495408.5, 2409544.2, 2557296.8, 3528628.5,
#         3377375.2, 3504139.8, 3457707.5, 3156010.2, 3616769. ],
#        dtype=float32)}

# %%
res=pd.DataFrame([test_data.id, y_pred]).T

# %%
res.head()
# Out:
#                id       Unnamed 0
# 0   877,392.00000 1,875,704.00000
# 1   201,483.00000 2,482,750.50000
# 2   188,674.00000 2,482,750.50000
# 3 1,211,067.00000 3,070,635.75000
# 4   883,437.00000 3,214,901.00000

# %%
res=res.rename(columns={"id": "id", "Unnamed 0": "valormt2_predicted"})

# %%
res.id=res.id.astype('int32')
res.valormt2_predicted=res.valormt2_predicted.astype('double')

# %%
res.head()
# Out:
#         id  valormt2_predicted
# 0   877392     1,875,704.00000
# 1   201483     2,482,750.50000
# 2   188674     2,482,750.50000
# 3  1211067     3,070,635.75000
# 4   883437     3,214,901.00000

# %%
res.shape
# Out:
# (53, 2)

# %%
res.valormt2_predicted=res.valormt2_predicted*0.90

# %%
res.to_csv(f'{PATH}/res_esto_no_se_hace_10.csv', index=False)
